# %%
# Import stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import json
import seaborn as sns
import re
import statistics

# %matplotlib inline

# %% [markdown]
# # Some Notes regarding this data(census)
#
# * I have included the data file layout in my data folder, so some of this is just repeated from there.
# * The estimates are based on the 2010 Census and were created without incorporation or consideration of the 2020 Census results.
# * All geographic boundaries for these population estimates are as of January 1, 2020.
# * An "A" in the 2010 Census field indicates a government that was formed or incorporated after the 2010 Census.

# %%
og_df = pd.read_csv('../data/census/city_pop_est_2010_2020.csv')
city_pop = og_df

# %%
og_df.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME  ... POPESTIMATE2011  POPESTIMATE2012  \
# 0          Alabama  Alabama  ...         4799642          4816632
# 1   Abbeville city  Alabama  ...            2694             2645
# 2  Adamsville city  Alabama  ...            4474             4453
# 3     Addison town  Alabama  ...             750              745
# 4       Akron town  Alabama  ...             347              347
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0          4831586          4843737          4854803          4866824
# 1             2629             2610             2602             2587
# 2             4430             4399             4371             4335
# 3              744              742              734              734
# 4              344              338              338              335
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020
# 0          4877989          4891628          4907965          4921532
# 1             2578             2565             2555             2553
# 2             4304             4285             4254             4211
# 3              728              725              723              717
# 4              332              332              328              327
#
# [5 rows x 23 columns]

# %%
# 'SUMLEV' code 40 will show the pop at a state level
state_pop = og_df[og_df['SUMLEV'] == 40]

# %%
state_pop.head()
# Out:
#       SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0         40      1       0      0       0       0             0        A
# 1109      40      2       0      0       0       0             0        A
# 1459      40      4       0      0       0       0             0        A
# 1680      40      5       0      0       0       0             0        A
# 2853      40      6       0      0       0       0             0        A
#
#             NAME      STNAME  ... POPESTIMATE2011  POPESTIMATE2012  \
# 0        Alabama     Alabama  ...         4799642          4816632
# 1109      Alaska      Alaska  ...          722349           730810
# 1459     Arizona     Arizona  ...         6473416          6556344
# 1680    Arkansas    Arkansas  ...         2941038          2952876
# 2853  California  California  ...        37636311         37944551
#
#       POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0             4831586          4843737          4854803          4866824
# 1109           737626           737075           738430           742575
# 1459          6634690          6732873          6832810          6944767
# 1680          2960459          2968759          2979732          2991815
# 2853         38253768         38586706         38904296         39149186
#
#       POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020
# 0             4877989          4891628          4907965          4921532
# 1109           740983           736624           733603           731158
# 1459          7048088          7164228          7291843          7421401
# 1680          3003855          3012161          3020985          3030522
# 2853         39337785         39437463         39437610         39368078
#
# [5 rows x 23 columns]

# %% [markdown]
# # Time to explore some of this data
# \
# I want to start with Nashville's population and find cities with similar sizes. \
# +- 10% of Nashville's pop should be good for cities within similar size

# %%
city_pop['SUMLEV'].value_counts()
# Out:
# 157    23705
# 61     21062
# 162    19494
# 71     13837
# 50      3143
# 172      115
# 40        51
# 170        8
# Name: SUMLEV, dtype: int64

# %%
'''
I will be using 'SUMLEV' 162 because that is the instance that specifies that entry is an 'incorporated place'

The census defines an 'incorporated place' as:
    "An incorporated place, under the Census Bureau's definition,[2] is a type of governmental unit incorporated under state law as a city, town (except the New England states, New York, and Wisconsin),[3] borough (except in Alaska and New York),
    [4] or village, and having legally prescribed limits, powers, and functions".
'''

city_pop = city_pop[city_pop['SUMLEV'] == 162]

# %%
# Dropping some unnecessary columns
city_pop = city_pop.drop(columns=['SUMLEV','STATE', 'COUNTY', 'PLACE', 'COUSUB', 'CONCIT', 'PRIMGEO_FLAG', 'FUNCSTAT'])

# Renaming some columns
city_pop = city_pop.rename(columns={"NAME": "CITY", "STNAME": "STATE"})

# %%
# A little bit of cleaning for use later.

city_pop['CITY'] = city_pop['CITY'].str.replace('city','')
city_pop.loc[(city_pop.CITY == 'Louisville/Jefferson County metro government (balance)'),'CITY']='Louisville'
city_pop.loc[(city_pop.CITY == 'Nashville-Davidson metropolitan government (balance)'),'CITY']='Nashville'
city_pop
# Out:
#                  CITY    STATE CENSUS2010POP  ESTIMATESBASE2010  \
# 1          Abbeville   Alabama          2688               2705
# 2         Adamsville   Alabama          4522               4487
# 3        Addison town  Alabama           758                754
# 4          Akron town  Alabama           356                356
# 5          Alabaster   Alabama         30352              31095
# ...               ...      ...           ...                ...
# 81264  Wamsutter town  Wyoming           451                451
# 81265  Wheatland town  Wyoming          3627               3629
# 81266        Worland   Wyoming          5487               5487
# 81267     Wright town  Wyoming          1807               1807
# 81268      Yoder town  Wyoming           151                151
#
#        POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 1                 2699             2694             2645             2629
# 2                 4481             4474             4453             4430
# 3                  751              750              745              744
# 4                  355              347              347              344
# 5                31192            31361            31673            31969
# ...                ...              ...              ...              ...
# 81264              450              452              463              488
# 81265             3626             3623             3628             3625
# 81266             5488             5437             5419             5423
# 81267             1810             1813             1863             1860
# 81268              152              153              156              159
#
#        POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 1                 2610             2602             2587             2578
# 2                 4399             4371             4335             4304
# 3                  742              734              734              728
# 4                  338              338              335              332
# 5                32177            32767            33040            33291
# ...                ...              ...              ...              ...
# 81264              509              502              494              485
# 81265             3645             3647             3592             3556
# 81266             5331             5336             5273             5160
# 81267             1856             1886             1862             1760
# 81268              161              160              158              158
#
#        POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020
# 1                 2565             2555             2553
# 2                 4285             4254             4211
# 3                  725              723              717
# 4                  332              328              327
# 5                33442            33522            33701
# ...                ...              ...              ...
# 81264              478              471              467
# 81265             3548             3494             3522
# 81266             5077             5037             4994
# 81267             1754             1751             1758
# 81268              157              156              156
#
# [19494 rows x 15 columns]

# %%
# Filtering by 2 criteria, trying to narrow down Nashville down to those within TN
# df loc - locate within this df the following: under the 'NAME' column, find all strings that contain 'Nashville'. Under the 'STNAME' column, limit it TN
nash_pop = city_pop.loc[(city_pop['CITY'].str.contains("Nashville")) & (city_pop['STATE']=='Tennessee')]

# %%
nash_pop
# Out:
#             CITY      STATE CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 70455  Nashville  Tennessee        601222             603465           604644
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 70455           612689           625824           636375           645741
#
#        POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 70455           656089           662344           664220           667772
#
#        POPESTIMATE2019  POPESTIMATE2020
# 70455           669725           671295

# %%
city_2020_pop = city_pop[['CITY', 'STATE', 'POPESTIMATE2020']]
city_2020_pop
# Out:
#                  CITY    STATE  POPESTIMATE2020
# 1          Abbeville   Alabama             2553
# 2         Adamsville   Alabama             4211
# 3        Addison town  Alabama              717
# 4          Akron town  Alabama              327
# 5          Alabaster   Alabama            33701
# ...               ...      ...              ...
# 81264  Wamsutter town  Wyoming              467
# 81265  Wheatland town  Wyoming             3522
# 81266        Worland   Wyoming             4994
# 81267     Wright town  Wyoming             1758
# 81268      Yoder town  Wyoming              156
#
# [19494 rows x 3 columns]

# %%
# Nash 2020 Pop Estimate
nash_2020_pop = nash_pop[['CITY', 'STATE', 'POPESTIMATE2020']]
nash_2020_pop
# Out:
#             CITY      STATE  POPESTIMATE2020
# 70455  Nashville  Tennessee           671295

# %%
# let's look at cities similar to Nash in terms of pop. I will use 5% (plus or minus) Nash Pop

upper_2020 = 671295*1.05
lower_2020 = 671295*0.95
nash_2020_pop
# Out:
#             CITY      STATE  POPESTIMATE2020
# 70455  Nashville  Tennessee           671295

# %%
similar_size_cities = city_2020_pop[((city_2020_pop['POPESTIMATE2020'] <= upper_2020) & (city_2020_pop['POPESTIMATE2020'] >= lower_2020))]
similar_size_cities
# Out:
#                  CITY          STATE  POPESTIMATE2020
# 28330         Boston   Massachusetts           691531
# 28996        Detroit        Michigan           665369
# 43978      Las Vegas          Nevada           662368
# 59874  Oklahoma City        Oklahoma           662314
# 61026       Portland          Oregon           656751
# 70434        Memphis       Tennessee           649705
# 70455       Nashville      Tennessee           671295
# 71496        El Paso           Texas           681534

# %%
# Let's clean this a bit

similar_size_cities['CITY'] = similar_size_cities['CITY'].str.replace('city','')
similar_size_cities.loc[(similar_size_cities.CITY == 'Nashville-Davidson metropolitan government (balance)'),'CITY']='Nashville'
similar_size_cities
# Out:
# <ipython-input-16-b5d0a5221c30>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similar_size_cities['CITY'] = similar_size_cities['CITY'].str.replace('city','')
# C:\Users\tye64\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                  CITY          STATE  POPESTIMATE2020
# 28330         Boston   Massachusetts           691531
# 28996        Detroit        Michigan           665369
# 43978      Las Vegas          Nevada           662368
# 59874  Oklahoma City        Oklahoma           662314
# 61026       Portland          Oregon           656751
# 70434        Memphis       Tennessee           649705
# 70455       Nashville      Tennessee           671295
# 71496        El Paso           Texas           681534

# %%
# Gonna save this to a csv to use on my other notebook.

# similar_size_cities.to_csv(r'../data/census/similar_size_cities.csv', index = False)

# %%
nash_pop
# Out:
#             CITY      STATE CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 70455  Nashville  Tennessee        601222             603465           604644
#
#        POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 70455           612689           625824           636375           645741
#
#        POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 70455           656089           662344           664220           667772
#
#        POPESTIMATE2019  POPESTIMATE2020
# 70455           669725           671295

# %%
# I want to do a quick visualization for Nash pop over the years. 

k = nash_pop.drop(columns = ['CITY', 'STATE', 'CENSUS2010POP', 'ESTIMATESBASE2010'])
transpose = k.T.reset_index()

# %%
transpose
# Out:
#               index   70455
# 0   POPESTIMATE2010  604644
# 1   POPESTIMATE2011  612689
# 2   POPESTIMATE2012  625824
# 3   POPESTIMATE2013  636375
# 4   POPESTIMATE2014  645741
# 5   POPESTIMATE2015  656089
# 6   POPESTIMATE2016  662344
# 7   POPESTIMATE2017  664220
# 8   POPESTIMATE2018  667772
# 9   POPESTIMATE2019  669725
# 10  POPESTIMATE2020  671295

# %%
# Let's clean this up

transpose = transpose.rename(columns={"index": "Year", 70455: "Estimated_Pop"})
transpose['Year'] = transpose.Year.str.replace('POPESTIMATE','')

# %%
transpose['Estimated_Pop'] = transpose['Estimated_Pop'].astype(int)
print(transpose.info())
transpose
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           11 non-null     object
#  1   Estimated_Pop  11 non-null     int32
# dtypes: int32(1), object(1)
# memory usage: 260.0+ bytes
# None
#     Year  Estimated_Pop
# 0   2010         604644
# 1   2011         612689
# 2   2012         625824
# 3   2013         636375
# 4   2014         645741
# 5   2015         656089
# 6   2016         662344
# 7   2017         664220
# 8   2018         667772
# 9   2019         669725
# 10  2020         671295

# %%
plt.style.use('classic')
plt.figure(figsize=(20, 9))

plt.plot(
    transpose['Year'],
    transpose['Estimated_Pop'],
    marker = 'o'
)

plt.xlabel("Year", fontsize=14)
plt.ylabel("Estimate Population", fontsize=14)
plt.title('Nashville Estimate Population')
# Out:
# Text(0.5, 1.0, 'Nashville Estimate Population')

# %%
# Looking at percent change each year

v = transpose
v['Pct_Change'] = v.Estimated_Pop.pct_change()
v
# Out:
#     Year  Estimated_Pop  Pct_Change
# 0   2010         604644         NaN
# 1   2011         612689    0.013305
# 2   2012         625824    0.021438
# 3   2013         636375    0.016859
# 4   2014         645741    0.014718
# 5   2015         656089    0.016025
# 6   2016         662344    0.009534
# 7   2017         664220    0.002832
# 8   2018         667772    0.005348
# 9   2019         669725    0.002925
# 10  2020         671295    0.002344

# %%
# Average percentage increase each year is right at 1%
y = v['Pct_Change'].mean()
y = y*100
y
# Out:
# 1.0532839822991402

# %%
# Percent change over the 10 year period
(transpose['Estimated_Pop'][10] - transpose['Estimated_Pop'][0])/transpose['Estimated_Pop'][0] * 100
# Out:
# 11.023180582293051

# %% [markdown]
# Lets assume that Nashville will grow at 11% every 10 years, or using the other calculation, 1% per year\
# We can calculate the population estimate for the next couple of decades. \
# We can then take those numbers and see what cities are currently at those levels.

# %%
# I'm going to hard code this because I'm a little stuck.

dict = {'Year':['2030','2040','2050'],
        'Estimated_Pop':[745138,827103,918084]
       }
  
df1 = pd.DataFrame(dict)
df1['Estimated_Pop'] = df1['Estimated_Pop'].astype(int)
df1.info()

  
forecast_pop = pd.concat([transpose, df1], ignore_index = True)
forecast_pop
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           3 non-null      object
#  1   Estimated_Pop  3 non-null      int32
# dtypes: int32(1), object(1)
# memory usage: 164.0+ bytes
#     Year  Estimated_Pop
# 0   2010         604644
# 1   2011         612689
# 2   2012         625824
# 3   2013         636375
# 4   2014         645741
# 5   2015         656089
# 6   2016         662344
# 7   2017         664220
# 8   2018         667772
# 9   2019         669725
# 10  2020         671295
# 11  2030         745138
# 12  2040         827103
# 13  2050         918084

# %%
# Let's find current similar cities as the forecasted 2030, 2040, 2050 pop of Nash. I will still use +-5% range.

upper_2030 = 745138*1.05
lower_2030 = 745138*0.95
nash_2030 = city_2020_pop[((city_2020_pop['POPESTIMATE2020'] <= upper_2030) & (city_2020_pop['POPESTIMATE2020'] >= lower_2030))]

upper_2040 = 827103*1.05
lower_2040 = 827103*0.95
nash_2040 = city_2020_pop[((city_2020_pop['POPESTIMATE2020'] <= upper_2040) & (city_2020_pop['POPESTIMATE2020'] >= lower_2040))]

upper_2050 = 918084*1.05
lower_2050 = 918084*0.95
nash_2050 = city_2020_pop[((city_2020_pop['POPESTIMATE2020'] <= upper_2050) & (city_2020_pop['POPESTIMATE2020'] >= lower_2050))]

# %%
nash_2030['CITY'] = nash_2030['CITY'].str.replace('city','')
nash_2030.loc[(nash_2030.CITY == 'Nashville-Davidson metropolitan government (balance)'),'CITY']='Nashville'
# nash_2030.to_csv(r'../data/census/nash_2030.csv', index = False)
nash_2030
# Out:
# <ipython-input-42-3172c206fb02>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nash_2030['CITY'] = nash_2030['CITY'].str.replace('city','')
# C:\Users\tye64\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#               CITY                 STATE  POPESTIMATE2020
# 3996       Denver               Colorado           735538
# 5034   Washington   District of Columbia           712816
# 76172     Seattle             Washington           769714

# %%
nash_2040['CITY'] = nash_2040['CITY'].str.replace('city','')
nash_2040.loc[(nash_2040.CITY == 'Indianapolis (balance)'),'CITY']='Indianapolis'
# nash_2040.to_csv(r'../data/census/nash_2040.csv', index = False)
nash_2040
# Out:
# <ipython-input-41-56d17f78fc50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nash_2040['CITY'] = nash_2040['CITY'].str.replace('city','')
# C:\Users\tye64\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                 CITY       STATE  POPESTIMATE2020
# 3226  San Francisco   California           866606

# %%
nash_2050['CITY'] = nash_2050['CITY'].str.replace('city','')
nash_2050.loc[(nash_2050.CITY == 'Indianapolis (balance)'),'CITY']='Indianapolis'
# nash_2050.to_csv(r'../data/census/nash_2050.csv', index = False)
nash_2050
# Out:
# <ipython-input-40-db0ab5e6fbf7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nash_2050['CITY'] = nash_2050['CITY'].str.replace('city','')
# C:\Users\tye64\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#                           CITY           STATE  POPESTIMATE2020
# 5209             Jacksonville          Florida           920570
# 15546  Indianapolis  (balance)         Indiana           877903
# 49715               Charlotte   North Carolina           900350
# 54071                Columbus             Ohio           903852
# 71532              Fort Worth            Texas           927720

# %% [markdown]
# # Let's make some graphs to compare Nash to similar sized cities

# %%
# Just a reminder on the similar sized cities table

similar_size_cities
# Out:
#                  CITY          STATE  POPESTIMATE2020
# 28330         Boston   Massachusetts           691531
# 28996        Detroit        Michigan           665369
# 43978      Las Vegas          Nevada           662368
# 59874  Oklahoma City        Oklahoma           662314
# 61026       Portland          Oregon           656751
# 70434        Memphis       Tennessee           649705
# 70455       Nashville      Tennessee           671295
# 71496        El Paso           Texas           681534

# %%
# Lets take a look at their population history. Going to 'join' it back to OG table

similar_cities_years = similar_size_cities.merge(city_pop, how = 'left', on = ['CITY', 'STATE'])
similar_cities_years
# Out:
#              CITY          STATE  POPESTIMATE2020_x CENSUS2010POP  \
# 0         Boston   Massachusetts             691531        617594
# 1        Detroit        Michigan             665369        713777
# 2      Las Vegas          Nevada             662368        583756
# 3  Oklahoma City        Oklahoma             662314        579999
# 4       Portland          Oregon             656751        583776
# 5        Memphis       Tennessee             649705        646889
# 6       Nashville      Tennessee             671295        601222
# 7        El Paso           Texas             681534        649121
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0             617779           621053           630620           643180
# 1             713956           711198           705202           700289
# 2             584500           584600           586682           593406
# 3             580494           582560           591042           601040
# 4             583810           585476           595610           604521
# 5             651874           652349           655434           658961
# 6             603465           604644           612689           625824
# 7             648079           650482           664141           674588
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0           653312           663260           670982           680218
# 1           691986           682746           679562           677379
# 2           599739           608216           617820           626952
# 3           612147           621673           632188           640010
# 4           610254           620975           631945           643065
# 5           657386           655299           654469           653026
# 6           636375           645741           656089           662344
# 7           674362           676664           675561           679001
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020_y
# 0           688239           692048           694661             691531
# 1           675031           673658           670442             665369
# 2           635746           644055           653963             662368
# 3           642903           648241           655334             662314
# 4           648176           651154           654378             656751
# 5           651398           651700           650998             649705
# 6           664220           667772           669725             671295
# 7           679978           678552           680028             681534

# %%
similar_cities_years = similar_cities_years.drop(columns = ['STATE','POPESTIMATE2020_x', 'ESTIMATESBASE2010', 'CENSUS2010POP', 'ESTIMATESBASE2010'])
similar_cities_years
# Out:
#              CITY  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0         Boston            621053           630620           643180
# 1        Detroit            711198           705202           700289
# 2      Las Vegas            584600           586682           593406
# 3  Oklahoma City            582560           591042           601040
# 4       Portland            585476           595610           604521
# 5        Memphis            652349           655434           658961
# 6       Nashville           604644           612689           625824
# 7        El Paso            650482           664141           674588
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# 0           653312           663260           670982           680218
# 1           691986           682746           679562           677379
# 2           599739           608216           617820           626952
# 3           612147           621673           632188           640010
# 4           610254           620975           631945           643065
# 5           657386           655299           654469           653026
# 6           636375           645741           656089           662344
# 7           674362           676664           675561           679001
#
#    POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE2020_y
# 0           688239           692048           694661             691531
# 1           675031           673658           670442             665369
# 2           635746           644055           653963             662368
# 3           642903           648241           655334             662314
# 4           648176           651154           654378             656751
# 5           651398           651700           650998             649705
# 6           664220           667772           669725             671295
# 7           679978           678552           680028             681534

# %%
r = similar_cities_years.set_index('CITY').T.reset_index()
r
# Out:
# CITY              index  Boston   Detroit   Las Vegas   Oklahoma City   \
# 0       POPESTIMATE2010   621053    711198      584600          582560
# 1       POPESTIMATE2011   630620    705202      586682          591042
# 2       POPESTIMATE2012   643180    700289      593406          601040
# 3       POPESTIMATE2013   653312    691986      599739          612147
# 4       POPESTIMATE2014   663260    682746      608216          621673
# 5       POPESTIMATE2015   670982    679562      617820          632188
# 6       POPESTIMATE2016   680218    677379      626952          640010
# 7       POPESTIMATE2017   688239    675031      635746          642903
# 8       POPESTIMATE2018   692048    673658      644055          648241
# 9       POPESTIMATE2019   694661    670442      653963          655334
# 10    POPESTIMATE2020_y   691531    665369      662368          662314
#
# CITY  Portland   Memphis   Nashville  El Paso
# 0        585476    652349     604644    650482
# 1        595610    655434     612689    664141
# 2        604521    658961     625824    674588
# 3        610254    657386     636375    674362
# 4        620975    655299     645741    676664
# 5        631945    654469     656089    675561
# 6        643065    653026     662344    679001
# 7        648176    651398     664220    679978
# 8        651154    651700     667772    678552
# 9        654378    650998     669725    680028
# 10       656751    649705     671295    681534

# %%
# Cleaning

r=r.rename(columns={"CITY": "index", 'index': "Year"})
r['Year'] = r['Year'].str.replace('POPESTIMATE','')
r['Year'] = r['Year'].str.replace('_y','')
similar_cities_year = r
similar_cities_year
# Out:
# CITY  Year  Boston   Detroit   Las Vegas   Oklahoma City   Portland   \
# 0     2010   621053    711198      584600          582560     585476
# 1     2011   630620    705202      586682          591042     595610
# 2     2012   643180    700289      593406          601040     604521
# 3     2013   653312    691986      599739          612147     610254
# 4     2014   663260    682746      608216          621673     620975
# 5     2015   670982    679562      617820          632188     631945
# 6     2016   680218    677379      626952          640010     643065
# 7     2017   688239    675031      635746          642903     648176
# 8     2018   692048    673658      644055          648241     651154
# 9     2019   694661    670442      653963          655334     654378
# 10    2020   691531    665369      662368          662314     656751
#
# CITY  Memphis   Nashville  El Paso
# 0       652349     604644    650482
# 1       655434     612689    664141
# 2       658961     625824    674588
# 3       657386     636375    674362
# 4       655299     645741    676664
# 5       654469     656089    675561
# 6       653026     662344    679001
# 7       651398     664220    679978
# 8       651700     667772    678552
# 9       650998     669725    680028
# 10      649705     671295    681534

# %%
list(similar_cities_year)
similar_cities_year = similar_cities_year.rename(columns={'Boston ':'Boston','Detroit ':'Detroit','Las Vegas ':'Las Vegas','Oklahoma City ':'Oklahoma City','Portland ':'Portland','Memphis ':'Memphis','El Paso ':'El Paso'})

# %%
plt.style.use('classic')
plt.figure(figsize=(20, 9))

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Nashville'],
    marker = 'D',
    label = 'Nashville',
    linewidth=2.0
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Boston'],
    marker = 'v',
    label = 'Boston',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Las Vegas'],
    marker = '^',
    label = 'Las Vegas',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Detroit'],
    marker = '1',
    label = 'Detroit',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Oklahoma City'],
    marker = '2',
    label = 'Oklahoma City',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Portland'],
    marker = '3',
    label = 'Portland',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['Memphis'],
    marker = '4',
    label = 'Memphis',
    alpha = 0.8
)

plt.plot(
    similar_cities_year['Year'],
    similar_cities_year['El Paso'],
    marker = 'o',
    label = 'El Paso',
    alpha = 0.8
)

plt.legend(loc = 'best')
plt.xlabel("Year", fontsize=14)
plt.ylabel("Estimate Population", fontsize=14)
plt.title('Nashville and Similar Sized Cities')
# Out:
# Text(0.5, 1.0, 'Nashville and Similar Sized Cities')
