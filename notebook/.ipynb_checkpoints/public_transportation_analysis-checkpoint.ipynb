# %%
# Import stuff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import json
import seaborn as sns
import re
import statistics
import sqldf

# %matplotlib inline

# %% [markdown]
# * **IMPORTANT** There is a readme within the excel files
# * Excel has multiple tabs. 'UPT' is the 'Unlinked Passenger Trips'
# * 'Unlinked Passenger Trips' is defined as "..total boardings on an individual vehicle."

# %%
og_upt_df = pd.read_excel('../data/public transportation/public_transport_data.xlsx', sheet_name = 'UPT', nrows=2225)
# Out:
# C:\Users\tye64\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
og_year_upt_df = pd.read_excel('../data/public transportation/public_transport_data.xlsx', sheet_name = 'Calendar_Year_UPT', nrows=2225)

# %%
og_year_upt_df
# Out:
#       5 digit NTD ID 4 digit NTD ID                                   Agency  \
# 0                  1              1  King County Department of Metro Transit
# 1                  1              1  King County Department of Metro Transit
# 2                  1              1  King County Department of Metro Transit
# 3                  1              1  King County Department of Metro Transit
# 4                  1              1  King County Department of Metro Transit
# ...              ...            ...                                      ...
# 2220           99423            NaN                         City of Glendale
# 2221           99424            NaN                         City of Pasadena
# 2222           99424            NaN                         City of Pasadena
# 2223           99425            NaN   Pomona Valley Transportation Authority
# 2224           99425            NaN   Pomona Valley Transportation Authority
#
#       Active  Reporter Type  UZA                            UZA Name Modes  \
# 0     Active  Full Reporter   14                         Seattle, WA    DR
# 1     Active  Full Reporter   14                         Seattle, WA    DR
# 2     Active  Full Reporter   14                         Seattle, WA    FB
# 3     Active  Full Reporter   14                         Seattle, WA    LR
# 4     Active  Full Reporter   14                         Seattle, WA    MB
# ...      ...            ...  ...                                 ...   ...
# 2220  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2221  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2222  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2223  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2224  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
#
#      TOS      2002  ...      2012      2013      2014       2015       2016  \
# 0     PT   1616625  ...   1119392   1103355   1012714     902626     870776
# 1     TX         0  ...     76736     86383     96244     110018     110665
# 2     DO         0  ...         0         0         0          0     601942
# 3     DO    357935  ...         0         0         0          0          0
# 4     DO  70032459  ...  94652420  97702518  99570061  101362882  100924131
# ...   ..       ...  ...       ...       ...       ...        ...        ...
# 2220  PT         0  ...         0         0         0     930377    1738122
# 2221  PT         0  ...         0         0         0          0          0
# 2222  PT         0  ...         0         0         0          0          0
# 2223  PT         0  ...         0         0         0      50926      99135
# 2224  TX         0  ...         0         0         0      34526      62726
#
#            2017       2018       2019      2020  2021 Through April
# 0        854155     883312     887915    455391              131615
# 1        103861     143747     177791     86460               24327
# 2        599954     664365     701608    146930               30834
# 3             0          0          0         0                   0
# 4     101129569  103435175  103527532  48865810            11668541
# ...         ...        ...        ...       ...                 ...
# 2220    1637300    1431136    1414940    553889              123060
# 2221      38773      86218      90957     38717                6746
# 2222     781755    1508413    1526844    957116              216266
# 2223      91053      84088      84110     30628                3671
# 2224      69445      68805      63067     37440                4374
#
# [2225 rows x 29 columns]

# %%
nash_year_upt = og_year_upt_df[og_upt_df['UZA Name'].str.contains('Nashville')]
nash_year_upt
# Out:
#       5 digit NTD ID 4 digit NTD ID  \
# 684            40004           4004
# 685            40004           4004
# 686            40004           4004
# 687            40004           4004
# 688            40004           4004
# 995            40159           4159
# 996            40159           4159
# 997            40159           4159
# 998            40159           4159
# 999            40159           4159
# 1014           40178           4178
#
#                                                Agency  Active  Reporter Type  \
# 684                    Metropolitan Transit Authority  Active  Full Reporter
# 685                    Metropolitan Transit Authority  Active  Full Reporter
# 686                    Metropolitan Transit Authority  Active  Full Reporter
# 687                    Metropolitan Transit Authority  Active  Full Reporter
# 688                    Metropolitan Transit Authority  Active  Full Reporter
# 995                 Regional Transportation Authority  Active  Full Reporter
# 996                 Regional Transportation Authority  Active  Full Reporter
# 997                 Regional Transportation Authority  Active  Full Reporter
# 998                 Regional Transportation Authority  Active  Full Reporter
# 999                 Regional Transportation Authority  Active  Full Reporter
# 1014  The Transportation Management Association Group  Active  Full Reporter
#
#       UZA                UZA Name Modes TOS     2002  ...     2012     2013  \
# 684    44  Nashville-Davidson, TN    CB  DO        0  ...        0        0
# 685    44  Nashville-Davidson, TN    DR  DO   116150  ...   289627   283563
# 686    44  Nashville-Davidson, TN    DR  PT        0  ...        0        0
# 687    44  Nashville-Davidson, TN    DR  TX        0  ...    97241   112972
# 688    44  Nashville-Davidson, TN    MB  DO  6590671  ...  9449084  9432768
# 995    44  Nashville-Davidson, TN    CB  PT        0  ...   139413   185394
# 996    44  Nashville-Davidson, TN    CR  PT        0  ...   264874   243496
# 997    44  Nashville-Davidson, TN    MB  PT        0  ...        0        0
# 998    44  Nashville-Davidson, TN    VP  DO        0  ...        0        0
# 999    44  Nashville-Davidson, TN    VP  PT        0  ...   185159   173843
# 1014   44  Nashville-Davidson, TN    VP  DO        0  ...    74768    63851
#
#          2014     2015     2016     2017     2018     2019     2020  \
# 684    201349   359813   333053   160949        0        0        0
# 685    314960   300945   290374   312262   313041   299585   178398
# 686         0        0        0        0        0        0        0
# 687    108428   132654   156006   146927   110655    94391    51154
# 688   9330265  9215774  8929525  8971288  9372784  9118379  4901327
# 995    202722   201989   191593   196108   184942   178981    56991
# 996    258023   273878   283174   299112   298765   293314    77245
# 997         0        0        0        0        0        0        0
# 998         0        0        0        0        0        0        0
# 999    176851   153928   136367   125245   119671    75901    35894
# 1014    73811    79625    95207   100426   117976   128461    92154
#
#       2021 Through April
# 684                    0
# 685                56064
# 686                    0
# 687                15092
# 688              1300872
# 995                 8970
# 996                11087
# 997                    0
# 998                    0
# 999                 4380
# 1014               25047
#
# [11 rows x 29 columns]

# %%
# Going to define the modes and then join it to my other df
# https://www.transit.dot.gov/ntd/national-transit-database-ntd-glossary#O

modes = {'Mode': ['AG','AR','CB','CC','CR','DR','FB','HR','IP','LR','MB','MG','MO','OR','PB','RB','SR','TB','TR','VP','YR'],
            'Name': ['Automated Guideway','Alaska Railroad','commuter bus','cable car','commuter rail','demand response','Ferryboats','heavy rail','inclined plane','light rail','motor bus','Monorail/Automated guideway','monorail','Over the Road Bus','publico','Bus Rapid Transit','Streetcar','Trolleybus','Aerial Tramway','vanpool','Hybrid rail']}

mode_def = pd.DataFrame(modes, columns = ['Mode', 'Name'])

# %%
mode_def['Name'] = mode_def['Name'].str.lower()

# %%
mode_def
# Out:
#    Mode                         Name
# 0    AG           automated guideway
# 1    AR              alaska railroad
# 2    CB                 commuter bus
# 3    CC                    cable car
# 4    CR                commuter rail
# 5    DR              demand response
# 6    FB                   ferryboats
# 7    HR                   heavy rail
# 8    IP               inclined plane
# 9    LR                   light rail
# 10   MB                    motor bus
# 11   MG  monorail/automated guideway
# 12   MO                     monorail
# 13   OR            over the road bus
# 14   PB                      publico
# 15   RB            bus rapid transit
# 16   SR                    streetcar
# 17   TB                   trolleybus
# 18   TR               aerial tramway
# 19   VP                      vanpool
# 20   YR                  hybrid rail

# %%
# Joining it to my df and rearranging columns

upt_df = og_upt_df
upt_df = upt_df.merge(mode_def, how = 'left', left_on = 'Modes', right_on = 'Mode')
o = list(upt_df)
o = ['5 digit NTD ID',
 '4 digit NTD ID',
 'Agency',
 'Active',
 'Reporter Type',
 'UZA',
 'UZA Name',
 'Modes',
 'Name',
 'TOS',
 'JAN02',
 'FEB02',
 'MAR02',
 'APR02',
 'MAY02',
 'JUN02',
 'JUL02',
 'AUG02',
 'SEP02',
 'OCT02',
 'NOV02',
 'DEC02',
 'JAN03',
 'FEB03',
 'MAR03',
 'APR03',
 'MAY03',
 'JUN03',
 'JUL03',
 'AUG03',
 'SEP03',
 'OCT03',
 'NOV03',
 'DEC03',
 'JAN04',
 'FEB04',
 'MAR04',
 'APR04',
 'MAY04',
 'JUN04',
 'JUL04',
 'AUG04',
 'SEP04',
 'OCT04',
 'NOV04',
 'DEC04',
 'JAN05',
 'FEB05',
 'MAR05',
 'APR05',
 'MAY05',
 'JUN05',
 'JUL05',
 'AUG05',
 'SEP05',
 'OCT05',
 'NOV05',
 'DEC05',
 'JAN06',
 'FEB06',
 'MAR06',
 'APR06',
 'MAY06',
 'JUN06',
 'JUL06',
 'AUG06',
 'SEP06',
 'OCT06',
 'NOV06',
 'DEC06',
 'JAN07',
 'FEB07',
 'MAR07',
 'APR07',
 'MAY07',
 'JUN07',
 'JUL07',
 'AUG07',
 'SEP07',
 'OCT07',
 'NOV07',
 'DEC07',
 'JAN08',
 'FEB08',
 'MAR08',
 'APR08',
 'MAY08',
 'JUN08',
 'JUL08',
 'AUG08',
 'SEP08',
 'OCT08',
 'NOV08',
 'DEC08',
 'JAN09',
 'FEB09',
 'MAR09',
 'APR09',
 'MAY09',
 'JUN09',
 'JUL09',
 'AUG09',
 'SEP09',
 'OCT09',
 'NOV09',
 'DEC09',
 'JAN10',
 'FEB10',
 'MAR10',
 'APR10',
 'MAY10',
 'JUN10',
 'JUL10',
 'AUG10',
 'SEP10',
 'OCT10',
 'NOV10',
 'DEC10',
 'JAN11',
 'FEB11',
 'MAR11',
 'APR11',
 'MAY11',
 'JUN11',
 'JUL11',
 'AUG11',
 'SEP11',
 'OCT11',
 'NOV11',
 'DEC11',
 'JAN12',
 'FEB12',
 'MAR12',
 'APR12',
 'MAY12',
 'JUN12',
 'JUL12',
 'AUG12',
 'SEP12',
 'OCT12',
 'NOV12',
 'DEC12',
 'JAN13',
 'FEB13',
 'MAR13',
 'APR13',
 'MAY13',
 'JUN13',
 'JUL13',
 'AUG13',
 'SEP13',
 'OCT13',
 'NOV13',
 'DEC13',
 'JAN14',
 'FEB14',
 'MAR14',
 'APR14',
 'MAY14',
 'JUN14',
 'JUL14',
 'AUG14',
 'SEP14',
 'OCT14',
 'NOV14',
 'DEC14',
 'JAN15',
 'FEB15',
 'MAR15',
 'APR15',
 'MAY15',
 'JUN15',
 'JUL15',
 'AUG15',
 'SEP15',
 'OCT15',
 'NOV15',
 'DEC15',
 'JAN16',
 'FEB16',
 'MAR16',
 'APR16',
 'MAY16',
 'JUN16',
 'JUL16',
 'AUG16',
 'SEP16',
 'OCT16',
 'NOV16',
 'DEC16',
 'JAN17',
 'FEB17',
 'MAR17',
 'APR17',
 'MAY17',
 'JUN17',
 'JUL17',
 'AUG17',
 'SEP17',
 'OCT17',
 'NOV17',
 'DEC17',
 'JAN18',
 'FEB18',
 'MAR18',
 'APR18',
 'MAY18',
 'JUN18',
 'JUL18',
 'AUG18',
 'SEP18',
 'OCT18',
 'NOV18',
 'DEC18',
 'JAN19',
 'FEB19',
 'MAR19',
 'APR19',
 'MAY19',
 'JUN19',
 'JUL19',
 'AUG19',
 'SEP19',
 'OCT19',
 'NOV19',
 'DEC19',
 'JAN20',
 'FEB20',
 'MAR20',
 'APR20',
 'MAY20',
 'JUN20',
 'JUL20',
 'AUG20',
 'SEP20',
 'OCT20',
 'NOV20',
 'DEC20',
 'JAN21',
 'FEB21',
 'MAR21',
 'APR21',
 'Mode']
upt_df = upt_df[o]

# %%
# I will likely not use this one. I will probably use the 'year' version.

upt_df = upt_df.drop(columns=['Mode'])
upt_df
# Out:
#       5 digit NTD ID 4 digit NTD ID                                   Agency  \
# 0                  1              1  King County Department of Metro Transit
# 1                  1              1  King County Department of Metro Transit
# 2                  1              1  King County Department of Metro Transit
# 3                  1              1  King County Department of Metro Transit
# 4                  1              1  King County Department of Metro Transit
# ...              ...            ...                                      ...
# 2220           99423            NaN                         City of Glendale
# 2221           99424            NaN                         City of Pasadena
# 2222           99424            NaN                         City of Pasadena
# 2223           99425            NaN   Pomona Valley Transportation Authority
# 2224           99425            NaN   Pomona Valley Transportation Authority
#
#       Active  Reporter Type  UZA                            UZA Name Modes  \
# 0     Active  Full Reporter   14                         Seattle, WA    DR
# 1     Active  Full Reporter   14                         Seattle, WA    DR
# 2     Active  Full Reporter   14                         Seattle, WA    FB
# 3     Active  Full Reporter   14                         Seattle, WA    LR
# 4     Active  Full Reporter   14                         Seattle, WA    MB
# ...      ...            ...  ...                                 ...   ...
# 2220  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2221  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2222  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2223  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2224  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
#
#                  Name TOS  ...      JUL20      AUG20      SEP20      OCT20  \
# 0     demand response  PT  ...    36591.0    33059.0    34071.0    36070.0
# 1     demand response  TX  ...     6416.0     5880.0     6650.0     6139.0
# 2          ferryboats  DO  ...     9643.0    10630.0     9801.0     8788.0
# 3          light rail  DO  ...        NaN        NaN        NaN        NaN
# 4           motor bus  DO  ...  3339926.0  3393742.0  3328392.0  3118656.0
# ...               ...  ..  ...        ...        ...        ...        ...
# 2220        motor bus  PT  ...    31203.0    31000.0    31100.0    29827.0
# 2221  demand response  PT  ...     2318.0     2449.0     2540.0     2833.0
# 2222        motor bus  PT  ...    67516.0    70993.0    71730.0    80812.0
# 2223  demand response  PT  ...     1715.0     1393.0     1671.0     1646.0
# 2224  demand response  TX  ...     2363.0     2385.0     2673.0     3076.0
#
#           NOV20      DEC20      JAN21      FEB21      MAR21      APR21
# 0       31020.0    31977.0    31199.0    28890.0    35712.0    35814.0
# 1        5929.0     4666.0     4177.0     4991.0     7078.0     8081.0
# 2        5586.0     6087.0     5355.0     5253.0     8573.0    11653.0
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4     2745130.0  2767733.0  2779426.0  2517179.0  3156235.0  3215701.0
# ...         ...        ...        ...        ...        ...        ...
# 2220    41897.0    30162.0    28863.0    28633.0    33085.0    32479.0
# 2221     2565.0     2200.0     2145.0     2022.0     2579.0        NaN
# 2222    73765.0    71309.0    66805.0    69252.0    80209.0        NaN
# 2223     2092.0     1747.0     1794.0     1877.0        NaN        NaN
# 2224     2210.0     2265.0     2129.0     2245.0        NaN        NaN
#
# [2225 rows x 242 columns]

# %%
year_upt_df = og_year_upt_df
year_upt_df = year_upt_df.merge(mode_def, how = 'left', left_on = 'Modes', right_on = 'Mode')
p = list(year_upt_df)
p = ['5 digit NTD ID',
 '4 digit NTD ID',
 'Agency',
 'Active',
 'Reporter Type',
 'UZA',
 'UZA Name',
 'Modes',
 'Name',
 'TOS',
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,
 2019,
 2020,
 '2021 Through April',
 'Mode']
year_upt_df = year_upt_df[p]
year_upt_df = year_upt_df.drop(columns=['Mode'])
year_upt_df = year_upt_df[year_upt_df['Active']=='Active']

# %%
year_upt_df
# Out:
#       5 digit NTD ID 4 digit NTD ID                                   Agency  \
# 0                  1              1  King County Department of Metro Transit
# 1                  1              1  King County Department of Metro Transit
# 2                  1              1  King County Department of Metro Transit
# 3                  1              1  King County Department of Metro Transit
# 4                  1              1  King County Department of Metro Transit
# ...              ...            ...                                      ...
# 2220           99423            NaN                         City of Glendale
# 2221           99424            NaN                         City of Pasadena
# 2222           99424            NaN                         City of Pasadena
# 2223           99425            NaN   Pomona Valley Transportation Authority
# 2224           99425            NaN   Pomona Valley Transportation Authority
#
#       Active  Reporter Type  UZA                            UZA Name Modes  \
# 0     Active  Full Reporter   14                         Seattle, WA    DR
# 1     Active  Full Reporter   14                         Seattle, WA    DR
# 2     Active  Full Reporter   14                         Seattle, WA    FB
# 3     Active  Full Reporter   14                         Seattle, WA    LR
# 4     Active  Full Reporter   14                         Seattle, WA    MB
# ...      ...            ...  ...                                 ...   ...
# 2220  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2221  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2222  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    MB
# 2223  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
# 2224  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim, CA    DR
#
#                  Name TOS  ...      2012      2013      2014       2015  \
# 0     demand response  PT  ...   1119392   1103355   1012714     902626
# 1     demand response  TX  ...     76736     86383     96244     110018
# 2          ferryboats  DO  ...         0         0         0          0
# 3          light rail  DO  ...         0         0         0          0
# 4           motor bus  DO  ...  94652420  97702518  99570061  101362882
# ...               ...  ..  ...       ...       ...       ...        ...
# 2220        motor bus  PT  ...         0         0         0     930377
# 2221  demand response  PT  ...         0         0         0          0
# 2222        motor bus  PT  ...         0         0         0          0
# 2223  demand response  PT  ...         0         0         0      50926
# 2224  demand response  TX  ...         0         0         0      34526
#
#            2016       2017       2018       2019      2020  2021 Through April
# 0        870776     854155     883312     887915    455391              131615
# 1        110665     103861     143747     177791     86460               24327
# 2        601942     599954     664365     701608    146930               30834
# 3             0          0          0          0         0                   0
# 4     100924131  101129569  103435175  103527532  48865810            11668541
# ...         ...        ...        ...        ...       ...                 ...
# 2220    1738122    1637300    1431136    1414940    553889              123060
# 2221          0      38773      86218      90957     38717                6746
# 2222          0     781755    1508413    1526844    957116              216266
# 2223      99135      91053      84088      84110     30628                3671
# 2224      62726      69445      68805      63067     37440                4374
#
# [2039 rows x 30 columns]

# %%
year_upt_df = year_upt_df.rename(columns={"UZA Name": "City"})

# %%
# I want to split the city and state

year_upt_df[['City','State']] = year_upt_df['City'].str.split(',',expand=True)

# %%
year_upt_df = year_upt_df[['5 digit NTD ID',
 '4 digit NTD ID',
 'Agency',
 'Active',
 'Reporter Type',
 'UZA',
 'City',
 'State',
 'Modes',
 'Name',
 'TOS',
 2002,
 2003,
 2004,
 2005,
 2006,
 2007,
 2008,
 2009,
 2010,
 2011,
 2012,
 2013,
 2014,
 2015,
 2016,
 2017,
 2018,
 2019,
 2020,
 '2021 Through April']]
year_upt_df
# Out:
#       5 digit NTD ID 4 digit NTD ID                                   Agency  \
# 0                  1              1  King County Department of Metro Transit
# 1                  1              1  King County Department of Metro Transit
# 2                  1              1  King County Department of Metro Transit
# 3                  1              1  King County Department of Metro Transit
# 4                  1              1  King County Department of Metro Transit
# ...              ...            ...                                      ...
# 2220           99423            NaN                         City of Glendale
# 2221           99424            NaN                         City of Pasadena
# 2222           99424            NaN                         City of Pasadena
# 2223           99425            NaN   Pomona Valley Transportation Authority
# 2224           99425            NaN   Pomona Valley Transportation Authority
#
#       Active  Reporter Type  UZA                            City State Modes  \
# 0     Active  Full Reporter   14                         Seattle    WA    DR
# 1     Active  Full Reporter   14                         Seattle    WA    DR
# 2     Active  Full Reporter   14                         Seattle    WA    FB
# 3     Active  Full Reporter   14                         Seattle    WA    LR
# 4     Active  Full Reporter   14                         Seattle    WA    MB
# ...      ...            ...  ...                             ...   ...   ...
# 2220  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim    CA    MB
# 2221  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim    CA    DR
# 2222  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim    CA    MB
# 2223  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim    CA    DR
# 2224  Active  Full Reporter    2  Los Angeles-Long Beach-Anaheim    CA    DR
#
#                  Name  ...      2012      2013      2014       2015  \
# 0     demand response  ...   1119392   1103355   1012714     902626
# 1     demand response  ...     76736     86383     96244     110018
# 2          ferryboats  ...         0         0         0          0
# 3          light rail  ...         0         0         0          0
# 4           motor bus  ...  94652420  97702518  99570061  101362882
# ...               ...  ...       ...       ...       ...        ...
# 2220        motor bus  ...         0         0         0     930377
# 2221  demand response  ...         0         0         0          0
# 2222        motor bus  ...         0         0         0          0
# 2223  demand response  ...         0         0         0      50926
# 2224  demand response  ...         0         0         0      34526
#
#            2016       2017       2018       2019      2020  2021 Through April
# 0        870776     854155     883312     887915    455391              131615
# 1        110665     103861     143747     177791     86460               24327
# 2        601942     599954     664365     701608    146930               30834
# 3             0          0          0          0         0                   0
# 4     100924131  101129569  103435175  103527532  48865810            11668541
# ...         ...        ...        ...        ...       ...                 ...
# 2220    1738122    1637300    1431136    1414940    553889              123060
# 2221          0      38773      86218      90957     38717                6746
# 2222          0     781755    1508413    1526844    957116              216266
# 2223      99135      91053      84088      84110     30628                3671
# 2224      62726      69445      68805      63067     37440                4374
#
# [2039 rows x 31 columns]

# %%
# Lets take a look at Nashville's 
nash_transport = year_upt_df.loc[year_upt_df['City'].str.contains("Nashville")]
nash_transport
# Out:
#       5 digit NTD ID 4 digit NTD ID  \
# 684            40004           4004
# 685            40004           4004
# 686            40004           4004
# 687            40004           4004
# 688            40004           4004
# 995            40159           4159
# 996            40159           4159
# 997            40159           4159
# 998            40159           4159
# 999            40159           4159
# 1014           40178           4178
#
#                                                Agency  Active  Reporter Type  \
# 684                    Metropolitan Transit Authority  Active  Full Reporter
# 685                    Metropolitan Transit Authority  Active  Full Reporter
# 686                    Metropolitan Transit Authority  Active  Full Reporter
# 687                    Metropolitan Transit Authority  Active  Full Reporter
# 688                    Metropolitan Transit Authority  Active  Full Reporter
# 995                 Regional Transportation Authority  Active  Full Reporter
# 996                 Regional Transportation Authority  Active  Full Reporter
# 997                 Regional Transportation Authority  Active  Full Reporter
# 998                 Regional Transportation Authority  Active  Full Reporter
# 999                 Regional Transportation Authority  Active  Full Reporter
# 1014  The Transportation Management Association Group  Active  Full Reporter
#
#       UZA                City State Modes             Name  ...     2012  \
# 684    44  Nashville-Davidson    TN    CB     commuter bus  ...        0
# 685    44  Nashville-Davidson    TN    DR  demand response  ...   289627
# 686    44  Nashville-Davidson    TN    DR  demand response  ...        0
# 687    44  Nashville-Davidson    TN    DR  demand response  ...    97241
# 688    44  Nashville-Davidson    TN    MB        motor bus  ...  9449084
# 995    44  Nashville-Davidson    TN    CB     commuter bus  ...   139413
# 996    44  Nashville-Davidson    TN    CR    commuter rail  ...   264874
# 997    44  Nashville-Davidson    TN    MB        motor bus  ...        0
# 998    44  Nashville-Davidson    TN    VP          vanpool  ...        0
# 999    44  Nashville-Davidson    TN    VP          vanpool  ...   185159
# 1014   44  Nashville-Davidson    TN    VP          vanpool  ...    74768
#
#          2013     2014     2015     2016     2017     2018     2019     2020  \
# 684         0   201349   359813   333053   160949        0        0        0
# 685    283563   314960   300945   290374   312262   313041   299585   178398
# 686         0        0        0        0        0        0        0        0
# 687    112972   108428   132654   156006   146927   110655    94391    51154
# 688   9432768  9330265  9215774  8929525  8971288  9372784  9118379  4901327
# 995    185394   202722   201989   191593   196108   184942   178981    56991
# 996    243496   258023   273878   283174   299112   298765   293314    77245
# 997         0        0        0        0        0        0        0        0
# 998         0        0        0        0        0        0        0        0
# 999    173843   176851   153928   136367   125245   119671    75901    35894
# 1014    63851    73811    79625    95207   100426   117976   128461    92154
#
#       2021 Through April
# 684                    0
# 685                56064
# 686                    0
# 687                15092
# 688              1300872
# 995                 8970
# 996                11087
# 997                    0
# 998                    0
# 999                 4380
# 1014               25047
#
# [11 rows x 31 columns]

# %%
# Going to import some CSVs from the Census worksheet. 

similar_cities = pd.read_csv('../data/census/similar_size_cities.csv')
nash_2030 = pd.read_csv('../data/census/nash_2030.csv')
nash_2040 = pd.read_csv('../data/census/nash_2040.csv')
nash_2050 = pd.read_csv('../data/census/nash_2050.csv')

# %%
similar_cities
# Out:
#              CITY          STATE  POPESTIMATE2020
# 0         Boston   Massachusetts           691531
# 1        Detroit        Michigan           665369
# 2      Las Vegas          Nevada           662368
# 3  Oklahoma City        Oklahoma           662314
# 4       Portland          Oregon           656751
# 5        Memphis       Tennessee           649705
# 6       Nashville      Tennessee           671295
# 7        El Paso           Texas           681534

# %%
nash_2030
# Out:
#           CITY                 STATE  POPESTIMATE2020
# 0      Denver               Colorado           735538
# 1  Washington   District of Columbia           712816
# 2     Seattle             Washington           769714

# %%
nash_2040
# Out:
#              CITY       STATE  POPESTIMATE2020
# 0  San Francisco   California           866606

# %%
nash_2050
# Out:
#                       CITY           STATE  POPESTIMATE2020
# 0            Jacksonville          Florida           920570
# 1  Indianapolis  (balance)         Indiana           877903
# 2               Charlotte   North Carolina           900350
# 3                Columbus             Ohio           903852
# 4              Fort Worth            Texas           927720

# %% [markdown]
# * I want to filter my public transportation DF to only include cities from the 4 census DFs
# * Not sure how to do this

# %%
Boston = year_upt_df.loc[year_upt_df['City'].str.contains("Boston")]
Detroit = year_upt_df.loc[year_upt_df['City'].str.contains("Detroit")]
Las_Vegas = year_upt_df.loc[year_upt_df['City'].str.contains("Las Vegas")]
Oklahoma_City = year_upt_df.loc[year_upt_df['City'].str.contains("Oklahoma City")]
Portland = year_upt_df.loc[year_upt_df['City'].str.contains("Portland")]
Memphis = year_upt_df.loc[year_upt_df['City'].str.contains("Memphis")]
El_Paso = year_upt_df.loc[year_upt_df['City'].str.contains("El Paso")]

# %%
Memphis
# Out:
#       5 digit NTD ID 4 digit NTD ID                    Agency  Active  \
# 679            40003           4003           City of Memphis  Active
# 680            40003           4003           City of Memphis  Active
# 681            40003           4003           City of Memphis  Active
# 682            40003           4003           City of Memphis  Active
# 683            40003           4003           City of Memphis  Active
# 1051           40247            NaN  Shelby County Government  Active
#
#       Reporter Type  UZA     City      State Modes             Name  ...  \
# 679   Full Reporter   41  Memphis   TN-MS-AR    DR  demand response  ...
# 680   Full Reporter   41  Memphis   TN-MS-AR    DR  demand response  ...
# 681   Full Reporter   41  Memphis   TN-MS-AR    LR       light rail  ...
# 682   Full Reporter   41  Memphis   TN-MS-AR    MB        motor bus  ...
# 683   Full Reporter   41  Memphis   TN-MS-AR    SR        streetcar  ...
# 1051  Full Reporter   41  Memphis   TN-MS-AR    VP          vanpool  ...
#
#          2012     2013     2014     2015     2016     2017     2018     2019  \
# 679    251177   245441   244195   218176   197419   195700   193491   189365
# 680         0        0        0        0        0        0        0        0
# 681         0        0        0        0        0        0        0        0
# 682   8523158  8565712  7894629  7731796  7263163  6683823  6051607  5662651
# 683   1492954  1366026   485131        0        0        0   302076   366666
# 1051        0        0        0        0        0        0    32897    34148
#
#          2020  2021 Through April
# 679    120369               36163
# 680         0                   0
# 681         0                   0
# 682   3203595              846310
# 683    101044               52639
# 1051        0                   0
#
# [6 rows x 31 columns]

# %%
Detroit.groupby('Name')[[2002,
                         2003,
                         2004,
                         2005,
                         2006,
                         2007,
                         2008,
                         2009,
                         2010,
                         2011,
                         2012,
                         2013,
                         2014,
                         2015,
                         2016,
                         2017,
                         2018,
                         2019,
                         2020,
                         '2021 Through April']].sum()
# Out:
#                                  2002      2003      2004      2005      2006  \
# Name
# automated guideway             274948    157697    950647   1792924   2368361
# demand response                941058    992645    956037    960213   1024700
# light rail                      25612     15185         0         0         0
# monorail/automated guideway         0         0         0         0         0
# motor bus                    48972086  48504648  48009711  44930689  47544675
# streetcar                           0         0         0         0         0
# vanpool                             0         0         0         0         0
#
#                                  2007      2008      2009      2010      2011  \
# Name
# automated guideway            2324429   2059714   2161436   2216800   2285358
# demand response               1032672   1054734   1025613   1044017   1013252
# light rail                          0         0         0         0         0
# monorail/automated guideway         0         0         0         0         0
# motor bus                    47143264  51711055  50232107  46222906  45237106
# streetcar                           0         0         0         0         0
# vanpool                             0         0         0         0         0
#
#                                  2012      2013      2014      2015      2016  \
# Name
# automated guideway                  0         0         0         0         0
# demand response                941714    960254    932473    857173    771679
# light rail                          0         0         0         0         0
# monorail/automated guideway   2298841   2207333   2357520   2409894   2165351
# motor bus                    42074171  37826850  33727688  33885296  34778957
# streetcar                           0         0         0         0         0
# vanpool                       1164251   1183168   1240344   1238351   1189241
#
#                                  2017      2018      2019      2020  \
# Name
# automated guideway                  0         0         0         0
# demand response                718364    768240    808132    526573
# light rail                          0         0         0         0
# monorail/automated guideway   2095415   1915173   1605583    269058
# motor bus                    31629441  31862216  31723408  14355257
# streetcar                     1011376   1232181   1093016    190479
# vanpool                       1176718    902693    871514    305108
#
#                              2021 Through April
# Name
# automated guideway                            0
# demand response                          169722
# light rail                                    0
# monorail/automated guideway                   0
# motor bus                               3101937
# streetcar                                     0
# vanpool                                   62388

# %%
# Fusion, ha.

j = pd.concat([Boston, Detroit,Las_Vegas,Oklahoma_City,Portland,Memphis,El_Paso,nash_transport])

# %%
bus = j[j['Name'] == 'motor bus']
bus_2019 = bus.groupby('City')[2019].sum()
bus_2019 = pd.DataFrame(bus_2019)
bus_2019 = bus_2019.reset_index()
bus_2019 = bus_2019.rename(columns={2019: "Count of Unlinked Passenger Trip"})
bus_2019
# Out:
#                   City  Count of Unlinked Passenger Trip
# 0               Boston                         107505367
# 1              Detroit                          31723408
# 2              El Paso                           9873514
# 3  Las Vegas-Henderson                          65528910
# 4              Memphis                           5662651
# 5   Nashville-Davidson                           9118379
# 6        Oklahoma City                           3032413
# 7             Portland                          65906015

# %%
bus_2019['Count in Millions'] = bus_2019['Count of Unlinked Passenger Trip']/1000000
bus_2019= bus_2019.sort_values(by='Count in Millions', ascending = False)
bus_2019
# Out:
#                   City  Count of Unlinked Passenger Trip  Count in Millions
# 0               Boston                         107505367         107.505367
# 7             Portland                          65906015          65.906015
# 3  Las Vegas-Henderson                          65528910          65.528910
# 1              Detroit                          31723408          31.723408
# 2              El Paso                           9873514           9.873514
# 5   Nashville-Davidson                           9118379           9.118379
# 4              Memphis                           5662651           5.662651
# 6        Oklahoma City                           3032413           3.032413

# %%
plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    bus_2019['City'],
    bus_2019['Count in Millions']
)

plt.xlabel("City", fontsize=16,fontweight='bold')
plt.ylabel("Count of Passenger Trips(Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Bus Ridership in 2019');

# %%
total_ridership = j.groupby('City')[2019].sum()
total_ridership = pd.DataFrame(total_ridership).reset_index().rename(columns={2019: "Count of Unlinked Passenger Trip"})
total_ridership['Count in Millions'] = total_ridership['Count of Unlinked Passenger Trip']/1000000
total_ridership= total_ridership.sort_values(by='Count in Millions', ascending = False)
total_ridership
# Out:
#                   City  Count of Unlinked Passenger Trip  Count in Millions
# 0               Boston                         373619884         373.619884
# 7             Portland                         114087759         114.087759
# 3  Las Vegas-Henderson                          66921123          66.921123
# 1              Detroit                          36101653          36.101653
# 2              El Paso                          10473050          10.473050
# 5   Nashville-Davidson                          10189012          10.189012
# 4              Memphis                           6252830           6.252830
# 6        Oklahoma City                           3466668           3.466668

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    total_ridership['City'],
    total_ridership['Count in Millions']
)

plt.xlabel("City", fontsize=16, fontweight='bold')
plt.ylabel("Count of Passenger Trips(Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Public Transportation Ridership in 2019');

# %%
stacked = total_ridership.merge(bus_2019, on = 'City')
stacked
# Out:
#                   City  Count of Unlinked Passenger Trip_x  \
# 0               Boston                           373619884
# 1             Portland                           114087759
# 2  Las Vegas-Henderson                            66921123
# 3              Detroit                            36101653
# 4              El Paso                            10473050
# 5   Nashville-Davidson                            10189012
# 6              Memphis                             6252830
# 7        Oklahoma City                             3466668
#
#    Count in Millions_x  Count of Unlinked Passenger Trip_y  \
# 0           373.619884                           107505367
# 1           114.087759                            65906015
# 2            66.921123                            65528910
# 3            36.101653                            31723408
# 4            10.473050                             9873514
# 5            10.189012                             9118379
# 6             6.252830                             5662651
# 7             3.466668                             3032413
#
#    Count in Millions_y
# 0           107.505367
# 1            65.906015
# 2            65.528910
# 3            31.723408
# 4             9.873514
# 5             9.118379
# 6             5.662651
# 7             3.032413

# %%
stacked = stacked[['City', 'Count in Millions_y','Count in Millions_x']]
stacked = stacked.rename(columns = {'Count in Millions_y': "Count of Bus Riders",'Count in Millions_x':'Total Ridership'})
stacked = stacked.sort_values(by='Total Ridership', ascending = False)
stacked
# Out:
#                   City  Count of Bus Riders  Total Ridership
# 0               Boston           107.505367       373.619884
# 1             Portland            65.906015       114.087759
# 2  Las Vegas-Henderson            65.528910        66.921123
# 3              Detroit            31.723408        36.101653
# 4              El Paso             9.873514        10.473050
# 5   Nashville-Davidson             9.118379        10.189012
# 6              Memphis             5.662651         6.252830
# 7        Oklahoma City             3.032413         3.466668

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    stacked['City'],
    stacked['Total Ridership'],
    label = 'Total Ridership'
)

plt.bar(
    stacked['City'],
    stacked['Count of Bus Riders'],
    label = 'Bus Ridership'
)

plt.xlabel("City", fontsize=16, fontweight='bold')
plt.ylabel("Count of Passenger Trips(Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend()
plt.title('Bus Ridership Compared to Overall Ridership in 2019');

# %%
# Let's take a look into Boston

b = Boston.groupby('Name')[[2019]].sum().reset_index().rename(columns={2019:'Ridership'})
b['Count in Million'] = b['Ridership']/1000000
b = b.sort_values(by='Count in Million', ascending = False)
b
# Out:
#                 Name  Ridership  Count in Million
# 5         heavy rail  159102449        159.102449
# 7          motor bus  107505367        107.505367
# 6         light rail   56383908         56.383908
# 2      commuter rail   31883589         31.883589
# 0  bus rapid transit   11626928         11.626928
# 8         trolleybus    3004461          3.004461
# 3    demand response    2417756          2.417756
# 4         ferryboats    1636006          1.636006
# 1       commuter bus      59420          0.059420

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    b['Name'],
    b['Count in Million']
)

plt.xlabel("Modes of Transport", fontsize=16, fontweight='bold')
plt.ylabel("Count of Passenger Trips(Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Bostons Modes of Transportation in 2019');

# %% [markdown]
# # I want to look at some of the financials

# %%
j['5 digit NTD ID'].value_counts()
# Out:
# 10003    10
# 60017     8
# 8         7
# 90045     5
# 60006     5
# 40159     5
# 40004     5
# 40003     5
# 58        4
# 50031     4
# 10005     4
# 24        4
# 50119     4
# 376       3
# 10013     3
# 10118     2
# 46        2
# 10053     2
# 50213     2
# 50141     2
# 10016     2
# 10004     2
# 40247     1
# 10069     1
# 10088     1
# 50193     1
# 40178     1
# 10115     1
# Name: 5 digit NTD ID, dtype: int64

# %%
# This data is for 2019

og_metric_df = pd.read_excel('../data/public transportation/Metrics_Static.xlsx', sheet_name = 'Metrics', nrows=3680)
og_metric_df
# Out:
#                                           Agency       City State  \
# 0                      MTA New York City Transit   New York    NY
# 1                      MTA New York City Transit   New York    NY
# 2                      MTA New York City Transit   New York    NY
# 3                      MTA New York City Transit   New York    NY
# 4                      MTA New York City Transit   New York    NY
# ...                                          ...        ...   ...
# 3675                  Lane County Transportation    Dighton    KS
# 3676            Quileute Tribe Community Shuttle    La Push    WA
# 3677                        Samish Indian Nation  Anacortes    WA
# 3678  City of Needles, dba: Needles Area Transit    Needles    CA
# 3679                               Fulton County  Johnstown    NY
#
#      Legacy NTD ID      NTD ID  \
# 0             2008       20008
# 1             2008       20008
# 2             2008       20008
# 3             2008       20008
# 4             2008       20008
# ...            ...         ...
# 3675      7R02-102  7R02-70197
# 3676           NaN         417
# 3677           NaN         455
# 3678      9R02-063  9R02-91020
# 3679      2R02-028  2R02-20964
#
#                                       Organization Type     Reporter Type  \
# 0     Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 1     Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 2     Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 3     Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# 4     Subsidiary Unit of a Transit Agency, Reporting...     Full Reporter
# ...                                                 ...               ...
# 3675  City, County or Local Government Unit or Depar...    Rural Reporter
# 3676                                              Tribe  Reduced Reporter
# 3677                                              Tribe  Reduced Reporter
# 3678  City, County or Local Government Unit or Depar...    Rural Reporter
# 3679  City, County or Local Government Unit or Depar...    Rural Reporter
#
#       Primary UZA\n Population  Agency VOMS Mode  ...  \
# 0                     18351295        10885   HR  ...
# 1                     18351295        10885   CB  ...
# 2                     18351295        10885   MB  ...
# 3                     18351295        10885   DR  ...
# 4                     18351295        10885   RB  ...
# ...                        ...          ...  ...  ...
# 3675                         0            1   DR  ...
# 3676                         0            1   MB  ...
# 3677                         0            1   DR  ...
# 3678                         0            1   MB  ...
# 3679                         0            1   MB  ...
#
#      Total Operating Expenses Questionable  Unlinked Passenger Trips  \
# 0                                      NaN                2712521697
# 1                                      NaN                  11477164
# 2                                      NaN                 691616614
# 3                                      NaN                   4828423
# 4                                      NaN                  30695695
# ...                                    ...                       ...
# 3675                                   NaN                      1166
# 3676                                   NaN                      1670
# 3677                                   NaN                        30
# 3678                                   NaN                     27623
# 3679                                   NaN                      2687
#
#       Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 0                                       NaN               19430373
# 1                                       NaN                 616233
# 2                                       NaN               12215926
# 3                                       NaN                3989579
# 4                                       NaN                 517519
# ...                                     ...                    ...
# 3675                                    NaN                    160
# 3676                                    NaN                   2087
# 3677                                    NaN                     10
# 3678                                    NaN                   3412
# 3679                                    NaN                   2868
#
#      Vehicle Revenue Hours Questionable  Passenger Miles  \
# 0                                   NaN      10462782577
# 1                                   NaN        153389117
# 2                                   NaN       1478429570
# 3                                   NaN         43330163
# 4                                   NaN         57076245
# ...                                 ...              ...
# 3675                                NaN                0
# 3676                                NaN                0
# 3677                                NaN                0
# 3678                                NaN                0
# 3679                                NaN                0
#
#       Passenger Miles Questionable  Vehicle Revenue Miles  \
# 0                              NaN              354616371
# 1                              NaN                9866807
# 2                              NaN               86233591
# 3                              NaN               37759280
# 4                              NaN                3382426
# ...                            ...                    ...
# 3675                           NaN                   6306
# 3676                           NaN                  46760
# 3677                           NaN                    262
# 3678                           NaN                  50028
# 3679                           NaN                  52631
#
#      Vehicle Revenue Miles Questionable  Any data questionable?
# 0                                   NaN                      No
# 1                                   NaN                      No
# 2                                   NaN                      No
# 3                                   NaN                      No
# 4                                   NaN                      No
# ...                                 ...                     ...
# 3675                                NaN                      No
# 3676                                NaN                      No
# 3677                                NaN                      No
# 3678                                NaN                      No
# 3679                                NaN                      No
#
# [3680 rows x 39 columns]

# %%
g = og_metric_df

# %%
e = j['5 digit NTD ID']
e
# Out:
# 145     10003
# 146     10003
# 147     10003
# 148     10003
# 149     10003
#         ...
# 996     40159
# 997     40159
# 998     40159
# 999     40159
# 1014    40178
# Name: 5 digit NTD ID, Length: 96, dtype: int64

# %%
g = g[g['NTD ID'].isin(e)]
g
# Out:
#                                           Agency      City State  \
# 34    Massachusetts Bay Transportation Authority    Boston    MA
# 35    Massachusetts Bay Transportation Authority    Boston    MA
# 36    Massachusetts Bay Transportation Authority    Boston    MA
# 37    Massachusetts Bay Transportation Authority    Boston    MA
# 38    Massachusetts Bay Transportation Authority    Boston    MA
# ...                                          ...       ...   ...
# 2147                            City of Portland  Portland    OR
# 2169                            City of Portland  Portland    OR
# 2686          Detroit Transportation Corporation   Detroit    MI
# 3102                M-1 Rail, dba: QLINE Detroit   Detroit    MI
# 3270           Casco Bay Island Transit District  Portland    ME
#
#      Legacy NTD ID NTD ID                                  Organization Type  \
# 34            1003  10003  Independent Public Agency or Authority of Tran...
# 35            1003  10003  Independent Public Agency or Authority of Tran...
# 36            1003  10003  Independent Public Agency or Authority of Tran...
# 37            1003  10003  Independent Public Agency or Authority of Tran...
# 38            1003  10003  Independent Public Agency or Authority of Tran...
# ...            ...    ...                                                ...
# 2147            58     58  City, County or Local Government Unit or Depar...
# 2169            58     58  City, County or Local Government Unit or Depar...
# 2686          5141  50141  Independent Public Agency or Authority of Tran...
# 3102          5213  50213                     Private-Non-Profit Corporation
# 3270          1088  10088  Independent Public Agency or Authority of Tran...
#
#       Reporter Type  Primary UZA\n Population  Agency VOMS Mode  ...  \
# 34    Full Reporter                   4181019         2464   FB  ...
# 35    Full Reporter                   4181019         2464   MB  ...
# 36    Full Reporter                   4181019         2464   MB  ...
# 37    Full Reporter                   4181019         2464   DR  ...
# 38    Full Reporter                   4181019         2464   CR  ...
# ...             ...                       ...          ...  ...  ...
# 2147  Full Reporter                   1849898           14   TR  ...
# 2169  Full Reporter                   1849898           14   SR  ...
# 2686  Full Reporter                   3734090            8   MG  ...
# 3102  Full Reporter                   3734090            5   SR  ...
# 3270  Full Reporter                    203914            4   FB  ...
#
#      Total Operating Expenses Questionable  Unlinked Passenger Trips  \
# 34                                     NaN                   1584440
# 35                                     NaN                  99301293
# 36                                     NaN                    951692
# 37                                     NaN                   1862279
# 38                                     NaN                  31177738
# ...                                    ...                       ...
# 2147                                   NaN                   2104368
# 2169                                   NaN                   4491362
# 2686                                   NaN                   1735852
# 3102                                   NaN                   1169213
# 3270                                   NaN                   1099820
#
#       Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 34                                      NaN                  24860
# 35                                      NaN                2721051
# 36                                        W                  88210
# 37                                      NaN                1417991
# 38                                      NaN                 829590
# ...                                     ...                    ...
# 2147                                    NaN                   3288
# 2169                                    NaN                  68730
# 2686                                    NaN                  42954
# 3102                                    NaN                  27290
# 3270                                    NaN                  16327
#
#      Vehicle Revenue Hours Questionable  Passenger Miles  \
# 34                                  NaN         13942294
# 35                                  NaN        255494460
# 36                                  NaN          2162081
# 37                                  NaN         14589884
# 38                                  NaN        653570994
# ...                                 ...              ...
# 2147                                NaN          1346796
# 2169                                NaN          5845765
# 2686                                NaN          2395476
# 3102                                NaN          1796000
# 3270                                NaN          3904361
#
#       Passenger Miles Questionable  Vehicle Revenue Miles  \
# 34                             NaN                 262174
# 35                             NaN               21357273
# 36                               W                1028451
# 37                             NaN               15610789
# 38                             NaN               24935847
# ...                            ...                    ...
# 2147                           NaN                  34294
# 2169                           NaN                 399542
# 2686                           NaN                 506223
# 3102                           NaN                 165463
# 3270                           NaN                  85249
#
#      Vehicle Revenue Miles Questionable  Any data questionable?
# 34                                  NaN                      No
# 35                                  NaN                      No
# 36                                  NaN                     Yes
# 37                                  NaN                      No
# 38                                  NaN                      No
# ...                                 ...                     ...
# 2147                                NaN                      No
# 2169                                NaN                      No
# 2686                                NaN                      No
# 3102                                NaN                      No
# 3270                                NaN                      No
#
# [70 rows x 39 columns]

# %%
f = j[['5 digit NTD ID','City']]
f
# Out:
#       5 digit NTD ID                City
# 145            10003              Boston
# 146            10003              Boston
# 147            10003              Boston
# 148            10003              Boston
# 149            10003              Boston
# ...              ...                 ...
# 996            40159  Nashville-Davidson
# 997            40159  Nashville-Davidson
# 998            40159  Nashville-Davidson
# 999            40159  Nashville-Davidson
# 1014           40178  Nashville-Davidson
#
# [96 rows x 2 columns]

# %%
u = g.merge(f, how = 'left', left_on = 'NTD ID', right_on = '5 digit NTD ID')
u
# Out:
#                                          Agency    City_x State Legacy NTD ID  \
# 0    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 1    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 2    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 3    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 4    Massachusetts Bay Transportation Authority    Boston    MA          1003
# ..                                          ...       ...   ...           ...
# 336          Detroit Transportation Corporation   Detroit    MI          5141
# 337          Detroit Transportation Corporation   Detroit    MI          5141
# 338                M-1 Rail, dba: QLINE Detroit   Detroit    MI          5213
# 339                M-1 Rail, dba: QLINE Detroit   Detroit    MI          5213
# 340           Casco Bay Island Transit District  Portland    ME          1088
#
#     NTD ID                                  Organization Type  Reporter Type  \
# 0    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 1    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 2    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 3    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 4    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# ..     ...                                                ...            ...
# 336  50141  Independent Public Agency or Authority of Tran...  Full Reporter
# 337  50141  Independent Public Agency or Authority of Tran...  Full Reporter
# 338  50213                     Private-Non-Profit Corporation  Full Reporter
# 339  50213                     Private-Non-Profit Corporation  Full Reporter
# 340  10088  Independent Public Agency or Authority of Tran...  Full Reporter
#
#      Primary UZA\n Population  Agency VOMS Mode  ...  \
# 0                     4181019         2464   FB  ...
# 1                     4181019         2464   FB  ...
# 2                     4181019         2464   FB  ...
# 3                     4181019         2464   FB  ...
# 4                     4181019         2464   FB  ...
# ..                        ...          ...  ...  ...
# 336                   3734090            8   MG  ...
# 337                   3734090            8   MG  ...
# 338                   3734090            5   SR  ...
# 339                   3734090            5   SR  ...
# 340                    203914            4   FB  ...
#
#     Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 0                                     NaN                  24860
# 1                                     NaN                  24860
# 2                                     NaN                  24860
# 3                                     NaN                  24860
# 4                                     NaN                  24860
# ..                                    ...                    ...
# 336                                   NaN                  42954
# 337                                   NaN                  42954
# 338                                   NaN                  27290
# 339                                   NaN                  27290
# 340                                   NaN                  16327
#
#      Vehicle Revenue Hours Questionable  Passenger Miles  \
# 0                                   NaN         13942294
# 1                                   NaN         13942294
# 2                                   NaN         13942294
# 3                                   NaN         13942294
# 4                                   NaN         13942294
# ..                                  ...              ...
# 336                                 NaN          2395476
# 337                                 NaN          2395476
# 338                                 NaN          1796000
# 339                                 NaN          1796000
# 340                                 NaN          3904361
#
#     Passenger Miles Questionable  Vehicle Revenue Miles  \
# 0                            NaN                 262174
# 1                            NaN                 262174
# 2                            NaN                 262174
# 3                            NaN                 262174
# 4                            NaN                 262174
# ..                           ...                    ...
# 336                          NaN                 506223
# 337                          NaN                 506223
# 338                          NaN                 165463
# 339                          NaN                 165463
# 340                          NaN                  85249
#
#      Vehicle Revenue Miles Questionable  Any data questionable?  \
# 0                                   NaN                      No
# 1                                   NaN                      No
# 2                                   NaN                      No
# 3                                   NaN                      No
# 4                                   NaN                      No
# ..                                  ...                     ...
# 336                                 NaN                      No
# 337                                 NaN                      No
# 338                                 NaN                      No
# 339                                 NaN                      No
# 340                                 NaN                      No
#
#     5 digit NTD ID    City_y
# 0            10003    Boston
# 1            10003    Boston
# 2            10003    Boston
# 3            10003    Boston
# 4            10003    Boston
# ..             ...       ...
# 336          50141   Detroit
# 337          50141   Detroit
# 338          50213   Detroit
# 339          50213   Detroit
# 340          10088  Portland
#
# [341 rows x 41 columns]

# %%
u = u[['Agency',
 'City_y',
 'State',
 'Legacy NTD ID',
 'NTD ID',
 'Organization Type',
 'Reporter Type',
 'Primary UZA\n Population',
 'Agency VOMS',
 'Mode',
 'TOS',
 'Mode VOMS',
 'Ratios:',
 'Fare Revenues per Unlinked Passenger Trip ',
 'Fare Revenues per Unlinked Passenger Trip Questionable',
 'Fare Revenues per Total Operating Expense (Recovery Ratio)',
 'Fare Revenues per Total Operating Expense (Recovery Ratio) Questionable',
 'Cost per\n Hour',
 'Cost per Hour Questionable',
 'Passengers per Hour',
 'Passengers per Hour Questionable',
 'Cost per Passenger',
 'Cost per Passenger Questionable',
 'Cost per Passenger Mile',
 'Cost per Passenger Mile Questionable',
 'Source Data:',
 'Fare Revenues Earned',
 'Fare Revenues Earned Questionable',
 'Total Operating Expenses',
 'Total Operating Expenses Questionable',
 'Unlinked Passenger Trips',
 'Unlinked Passenger Trips Questionable',
 'Vehicle Revenue Hours',
 'Vehicle Revenue Hours Questionable',
 'Passenger Miles',
 'Passenger Miles Questionable',
 'Vehicle Revenue Miles',
 'Vehicle Revenue Miles Questionable',
 'Any data questionable?']]
u = u.rename(columns = {'City_y':'City'})

# %%
u
# Out:
#                                          Agency      City State Legacy NTD ID  \
# 0    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 1    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 2    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 3    Massachusetts Bay Transportation Authority    Boston    MA          1003
# 4    Massachusetts Bay Transportation Authority    Boston    MA          1003
# ..                                          ...       ...   ...           ...
# 336          Detroit Transportation Corporation   Detroit    MI          5141
# 337          Detroit Transportation Corporation   Detroit    MI          5141
# 338                M-1 Rail, dba: QLINE Detroit   Detroit    MI          5213
# 339                M-1 Rail, dba: QLINE Detroit   Detroit    MI          5213
# 340           Casco Bay Island Transit District  Portland    ME          1088
#
#     NTD ID                                  Organization Type  Reporter Type  \
# 0    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 1    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 2    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 3    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# 4    10003  Independent Public Agency or Authority of Tran...  Full Reporter
# ..     ...                                                ...            ...
# 336  50141  Independent Public Agency or Authority of Tran...  Full Reporter
# 337  50141  Independent Public Agency or Authority of Tran...  Full Reporter
# 338  50213                     Private-Non-Profit Corporation  Full Reporter
# 339  50213                     Private-Non-Profit Corporation  Full Reporter
# 340  10088  Independent Public Agency or Authority of Tran...  Full Reporter
#
#      Primary UZA\n Population  Agency VOMS Mode  ...  \
# 0                     4181019         2464   FB  ...
# 1                     4181019         2464   FB  ...
# 2                     4181019         2464   FB  ...
# 3                     4181019         2464   FB  ...
# 4                     4181019         2464   FB  ...
# ..                        ...          ...  ...  ...
# 336                   3734090            8   MG  ...
# 337                   3734090            8   MG  ...
# 338                   3734090            5   SR  ...
# 339                   3734090            5   SR  ...
# 340                    203914            4   FB  ...
#
#     Total Operating Expenses Questionable  Unlinked Passenger Trips  \
# 0                                     NaN                   1584440
# 1                                     NaN                   1584440
# 2                                     NaN                   1584440
# 3                                     NaN                   1584440
# 4                                     NaN                   1584440
# ..                                    ...                       ...
# 336                                   NaN                   1735852
# 337                                   NaN                   1735852
# 338                                   NaN                   1169213
# 339                                   NaN                   1169213
# 340                                   NaN                   1099820
#
#      Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 0                                      NaN                  24860
# 1                                      NaN                  24860
# 2                                      NaN                  24860
# 3                                      NaN                  24860
# 4                                      NaN                  24860
# ..                                     ...                    ...
# 336                                    NaN                  42954
# 337                                    NaN                  42954
# 338                                    NaN                  27290
# 339                                    NaN                  27290
# 340                                    NaN                  16327
#
#     Vehicle Revenue Hours Questionable  Passenger Miles  \
# 0                                  NaN         13942294
# 1                                  NaN         13942294
# 2                                  NaN         13942294
# 3                                  NaN         13942294
# 4                                  NaN         13942294
# ..                                 ...              ...
# 336                                NaN          2395476
# 337                                NaN          2395476
# 338                                NaN          1796000
# 339                                NaN          1796000
# 340                                NaN          3904361
#
#      Passenger Miles Questionable  Vehicle Revenue Miles  \
# 0                             NaN                 262174
# 1                             NaN                 262174
# 2                             NaN                 262174
# 3                             NaN                 262174
# 4                             NaN                 262174
# ..                            ...                    ...
# 336                           NaN                 506223
# 337                           NaN                 506223
# 338                           NaN                 165463
# 339                           NaN                 165463
# 340                           NaN                  85249
#
#     Vehicle Revenue Miles Questionable  Any data questionable?
# 0                                  NaN                      No
# 1                                  NaN                      No
# 2                                  NaN                      No
# 3                                  NaN                      No
# 4                                  NaN                      No
# ..                                 ...                     ...
# 336                                NaN                      No
# 337                                NaN                      No
# 338                                NaN                      No
# 339                                NaN                      No
# 340                                NaN                      No
#
# [341 rows x 39 columns]

# %%
fares = u.groupby(['City'])['Fare Revenues Earned'].sum()
fares = pd.DataFrame(fares).reset_index()
fares['In Millions'] = fares['Fare Revenues Earned']/1000000
fares = fares.sort_values(by = 'In Millions', ascending = False)
fares
# Out:
#                   City  Fare Revenues Earned  In Millions
# 0               Boston            6736179315  6736.179315
# 7             Portland             859162895   859.162895
# 3  Las Vegas-Henderson             335718730   335.718730
# 1              Detroit             132808048   132.808048
# 5   Nashville-Davidson              50053869    50.053869
# 2              El Paso              39884375    39.884375
# 4              Memphis              30987559    30.987559
# 6        Oklahoma City              21105072    21.105072

# %%
expenses = u.groupby(['City'])['Total Operating Expenses'].sum()
expenses = pd.DataFrame(expenses).reset_index()
expenses['In Millions'] = expenses['Total Operating Expenses']/1000000
expenses = expenses.sort_values(by = 'In Millions', ascending = False)
expenses
# Out:
#                   City  Total Operating Expenses   In Millions
# 0               Boston               15219699986  15219.699986
# 7             Portland                4044795195   4044.795195
# 3  Las Vegas-Henderson                1187377560   1187.377560
# 1              Detroit                 955648026    955.648026
# 5   Nashville-Davidson                 452878244    452.878244
# 2              El Paso                 326241895    326.241895
# 4              Memphis                 291847881    291.847881
# 6        Oklahoma City                 248931472    248.931472

# %%
fe = fares.merge(expenses, on = 'City')
fe = fe.rename(columns = {'In Millions_x':'Renenues in Millions', 'In Millions_y':'Expenses in Millions'})
fe
# Out:
#                   City  Fare Revenues Earned  Renenues in Millions  \
# 0               Boston            6736179315           6736.179315
# 1             Portland             859162895            859.162895
# 2  Las Vegas-Henderson             335718730            335.718730
# 3              Detroit             132808048            132.808048
# 4   Nashville-Davidson              50053869             50.053869
# 5              El Paso              39884375             39.884375
# 6              Memphis              30987559             30.987559
# 7        Oklahoma City              21105072             21.105072
#
#    Total Operating Expenses  Expenses in Millions
# 0               15219699986          15219.699986
# 1                4044795195           4044.795195
# 2                1187377560           1187.377560
# 3                 955648026            955.648026
# 4                 452878244            452.878244
# 5                 326241895            326.241895
# 6                 291847881            291.847881
# 7                 248931472            248.931472

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    fe['City'],
    fe['Expenses in Millions'],
    label = 'Total Expenses in Millions',
    color = 'orange'
)

plt.bar(
    fe['City'],
    fe['Renenues in Millions'],
    label = 'Fare Renenues in Millions',
    color = 'blue'
)

plt.xlabel("City", fontsize=16, fontweight='bold')
plt.ylabel("Dollars (Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend()
plt.title('Revenue and Expenses in 2019');

# %%
i = j.groupby(['City','Name'])[2019].sum()
city_modes = pd.DataFrame(i)
city_modes = city_modes.reset_index()
city_modes = city_modes.rename(columns = {2019:'Count of Passenger Trips'}).sort_values(by = ['City','Count of Passenger Trips'], ascending = False)
city_modes
# Out:
#                    City                         Name  Count of Passenger Trips
# 45             Portland                    motor bus                  65906015
# 44             Portland                   light rail                  38388070
# 46             Portland                    streetcar                   4097594
# 38             Portland               aerial tramway                   2202197
# 41             Portland              demand response                   1412272
# 42             Portland                   ferryboats                   1104433
# 40             Portland                commuter rail                    574692
# 43             Portland                  hybrid rail                    361612
# 47             Portland                      vanpool                     40874
# 39             Portland                 commuter bus                         0
# 35        Oklahoma City                    motor bus                   3032413
# 36        Oklahoma City                    streetcar                    365678
# 33        Oklahoma City              demand response                     60001
# 34        Oklahoma City                   ferryboats                      4437
# 37        Oklahoma City                      vanpool                      4139
# 31   Nashville-Davidson                    motor bus                   9118379
# 30   Nashville-Davidson              demand response                    393976
# 29   Nashville-Davidson                commuter rail                    293314
# 32   Nashville-Davidson                      vanpool                    204362
# 28   Nashville-Davidson                 commuter bus                    178981
# 25              Memphis                    motor bus                   5662651
# 26              Memphis                    streetcar                    366666
# 23              Memphis              demand response                    189365
# 27              Memphis                      vanpool                     34148
# 24              Memphis                   light rail                         0
# 22  Las Vegas-Henderson                    motor bus                  65528910
# 21  Las Vegas-Henderson              demand response                   1392213
# 19  Las Vegas-Henderson            bus rapid transit                         0
# 20  Las Vegas-Henderson                 commuter bus                         0
# 17              El Paso                    motor bus                   9873514
# 16              El Paso              demand response                    326560
# 18              El Paso                    streetcar                    272976
# 13              Detroit                    motor bus                  31723408
# 12              Detroit  monorail/automated guideway                   1605583
# 14              Detroit                    streetcar                   1093016
# 15              Detroit                      vanpool                    871514
# 10              Detroit              demand response                    808132
# 9               Detroit           automated guideway                         0
# 11              Detroit                   light rail                         0
# 5                Boston                   heavy rail                 159102449
# 7                Boston                    motor bus                 107505367
# 6                Boston                   light rail                  56383908
# 2                Boston                commuter rail                  31883589
# 0                Boston            bus rapid transit                  11626928
# 8                Boston                   trolleybus                   3004461
# 3                Boston              demand response                   2417756
# 4                Boston                   ferryboats                   1636006
# 1                Boston                 commuter bus                     59420

# %%
nash_2050
# Out:
#                       CITY           STATE  POPESTIMATE2020
# 0            Jacksonville          Florida           920570
# 1  Indianapolis  (balance)         Indiana           877903
# 2               Charlotte   North Carolina           900350
# 3                Columbus             Ohio           903852
# 4              Fort Worth            Texas           927720

# %%
Denver = year_upt_df.loc[year_upt_df['City'].str.contains("Denver")]
Washington = year_upt_df.loc[year_upt_df['City'].str.contains("Washington")]
Seattle = year_upt_df.loc[year_upt_df['City'].str.contains("Seattle")]
San_Francisco = year_upt_df.loc[year_upt_df['City'].str.contains("San Francisco")]
Jacksonville = year_upt_df.loc[year_upt_df['City'].str.contains("Jacksonville")]
Indianapolis = year_upt_df.loc[year_upt_df['City'].str.contains("Indianapolis")]
Columbus = year_upt_df.loc[year_upt_df['City'].str.contains("Columbus")]
Fort_Worth = year_upt_df.loc[year_upt_df['City'].str.contains("Fort Worth")]

# %%
smash = pd.concat([Denver, Washington,Seattle,San_Francisco,Jacksonville,Indianapolis,Columbus, Fort_Worth,nash_transport])
smash
# Out:
#       5 digit NTD ID 4 digit NTD ID  \
# 1772           80006           8006
# 1773           80006           8006
# 1774           80006           8006
# 1775           80006           8006
# 1776           80006           8006
# ...              ...            ...
# 996            40159           4159
# 997            40159           4159
# 998            40159           4159
# 999            40159           4159
# 1014           40178           4178
#
#                                                Agency  Active  Reporter Type  \
# 1772          Denver Regional Transportation District  Active  Full Reporter
# 1773          Denver Regional Transportation District  Active  Full Reporter
# 1774          Denver Regional Transportation District  Active  Full Reporter
# 1775          Denver Regional Transportation District  Active  Full Reporter
# 1776          Denver Regional Transportation District  Active  Full Reporter
# ...                                               ...     ...            ...
# 996                 Regional Transportation Authority  Active  Full Reporter
# 997                 Regional Transportation Authority  Active  Full Reporter
# 998                 Regional Transportation Authority  Active  Full Reporter
# 999                 Regional Transportation Authority  Active  Full Reporter
# 1014  The Transportation Management Association Group  Active  Full Reporter
#
#       UZA                City State Modes             Name  ...      2012  \
# 1772   18       Denver-Aurora    CO    CR    commuter rail  ...         0
# 1773   18       Denver-Aurora    CO    CR    commuter rail  ...         0
# 1774   18       Denver-Aurora    CO    DR  demand response  ...     38680
# 1775   18       Denver-Aurora    CO    DR  demand response  ...   1124141
# 1776   18       Denver-Aurora    CO    LR       light rail  ...  20639068
# ...   ...                 ...   ...   ...              ...  ...       ...
# 996    44  Nashville-Davidson    TN    CR    commuter rail  ...    264874
# 997    44  Nashville-Davidson    TN    MB        motor bus  ...         0
# 998    44  Nashville-Davidson    TN    VP          vanpool  ...         0
# 999    44  Nashville-Davidson    TN    VP          vanpool  ...    185159
# 1014   44  Nashville-Davidson    TN    VP          vanpool  ...     74768
#
#           2013      2014      2015      2016      2017      2018      2019  \
# 1772         0         0         0         0         0         0         0
# 1773         0         0         0   4317405   6950256   7619589   9711377
# 1774     55968     20406         0         0         0         0         0
# 1775   1174258   1250054   1229366   1185958   1215468   1226319   1179015
# 1776  23773843  26363053  25518578  24585082  24645459  25322058  24585300
# ...        ...       ...       ...       ...       ...       ...       ...
# 996     243496    258023    273878    283174    299112    298765    293314
# 997          0         0         0         0         0         0         0
# 998          0         0         0         0         0         0         0
# 999     173843    176851    153928    136367    125245    119671     75901
# 1014     63851     73811     79625     95207    100426    117976    128461
#
#           2020  2021 Through April
# 1772    173765              178234
# 1773   4780402             1408183
# 1774         0                   0
# 1775    541749              161009
# 1776  10464678             2332225
# ...        ...                 ...
# 996      77245               11087
# 997          0                   0
# 998          0                   0
# 999      35894                4380
# 1014     92154               25047
#
# [184 rows x 31 columns]

# %%
s = smash.groupby('City')[2019].sum()
s = pd.DataFrame(s).reset_index().rename(columns = {2019: 'Count of Passenger Trip'})
s['Count in Millions'] = s['Count of Passenger Trip']/1000000
s = s.sort_values(by = 'Count in Millions', ascending = False)
s['City'] = s['City'].str.replace('Dallas-Fort Worth-Arlington','Dallas-Fort')
s
# Out:
#                     City  Count of Passenger Trip  Count in Millions
# 6  San Francisco-Oakland                444902197         444.902197
# 8             Washington                420971676         420.971676
# 7                Seattle                224989946         224.989946
# 2          Denver-Aurora                105375108         105.375108
# 1            Dallas-Fort                 76670186          76.670186
# 0               Columbus                 19572009          19.572009
# 4           Jacksonville                 11458624          11.458624
# 5     Nashville-Davidson                 10189012          10.189012
# 3           Indianapolis                  9701062           9.701062

# %%
m = smash['5 digit NTD ID']
n = og_metric_df
m = n[n['NTD ID'].isin(m)]
m
# Out:
#                                               Agency           City State  \
# 19    Washington Metropolitan Area Transit Authority     Washington    DC
# 20    Washington Metropolitan Area Transit Authority     Washington    DC
# 21    Washington Metropolitan Area Transit Authority     Washington    DC
# 22    Washington Metropolitan Area Transit Authority     Washington    DC
# 23    Washington Metropolitan Area Transit Authority     Washington    DC
# ...                                              ...            ...   ...
# 2691   City of Seattle, dba: Seattle Center Monorail        Seattle    WA
# 2722   City of Grand Prairie , dba: Grand Connection  Grand Prairie    TX
# 2731                   City of Fairfax, dba: CUE Bus        Fairfax    VA
# 3058               McKinney Avenue Transit Authority         Dallas    TX
# 3535                                County of Pierce         Tacoma    WA
#
#      Legacy NTD ID NTD ID                                  Organization Type  \
# 19            3030  30030  Independent Public Agency or Authority of Tran...
# 20            3030  30030  Independent Public Agency or Authority of Tran...
# 21            3030  30030  Independent Public Agency or Authority of Tran...
# 22            3030  30030  Independent Public Agency or Authority of Tran...
# 23            3030  30030  Independent Public Agency or Authority of Tran...
# ...            ...    ...                                                ...
# 2691            23     23  City, County or Local Government Unit or Depar...
# 2722          6068  60068  City, County or Local Government Unit or Depar...
# 2731          3058  30058  City, County or Local Government Unit or Depar...
# 3058          6133  60133                     Private-Non-Profit Corporation
# 3535            28     28  City, County or Local Government Unit or Depar...
#
#          Reporter Type  Primary UZA\n Population  Agency VOMS Mode  ...  \
# 19       Full Reporter                   4586770         3391   MB  ...
# 20       Full Reporter                   4586770         3391   HR  ...
# 21       Full Reporter                   4586770         3391   DR  ...
# 22       Full Reporter                   4586770         3391   DT  ...
# 23       Full Reporter                   4586770         3391   MB  ...
# ...                ...                       ...          ...  ...  ...
# 2691     Full Reporter                   3059393            8   MG  ...
# 2722  Reduced Reporter                   5121892            8   DR  ...
# 2731     Full Reporter                   4586770            8   MB  ...
# 3058     Full Reporter                   5121892            5   SR  ...
# 3535     Full Reporter                   3059393            2   FB  ...
#
#      Total Operating Expenses Questionable  Unlinked Passenger Trips  \
# 19                                     NaN                   1206050
# 20                                     NaN                 228974810
# 21                                     NaN                   2212686
# 22                                     NaN                    135638
# 23                                     NaN                 122127065
# ...                                    ...                       ...
# 2691                                   NaN                   1939224
# 2722                                   NaN                     53404
# 2731                                   NaN                    601813
# 3058                                   NaN                    571801
# 3535                                   NaN                    460515
#
#       Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 19                                      NaN                  57911
# 20                                      NaN                3667616
# 21                                      NaN                2122506
# 22                                      NaN                  91841
# 23                                      NaN                3726938
# ...                                     ...                    ...
# 2691                                    NaN                  20041
# 2722                                    NaN                  13057
# 2731                                    NaN                  34273
# 3058                                    NaN                  12995
# 3535                                    NaN                   5248
#
#      Vehicle Revenue Hours Questionable  Passenger Miles  \
# 19                                  NaN          9025834
# 20                                  NaN       1313511151
# 21                                  NaN         21875322
# 22                                  NaN          2502448
# 23                                  NaN        358532948
# ...                                 ...              ...
# 2691                                NaN          1745302
# 2722                                NaN                0
# 2731                                NaN          2040146
# 3058                                NaN           721986
# 3535                                NaN          1823639
#
#       Passenger Miles Questionable  Vehicle Revenue Miles  \
# 19                             NaN                 901961
# 20                             NaN               85106645
# 21                             NaN               19685883
# 22                             NaN                2283499
# 23                             NaN               36511319
# ...                            ...                    ...
# 2691                           NaN                 195517
# 2722                           NaN                 140835
# 2731                           NaN                 435847
# 3058                           NaN                  61459
# 3535                           NaN                  41557
#
#      Vehicle Revenue Miles Questionable  Any data questionable?
# 19                                  NaN                      No
# 20                                  NaN                      No
# 21                                  NaN                      No
# 22                                  NaN                      No
# 23                                  NaN                      No
# ...                                 ...                     ...
# 2691                                NaN                      No
# 2722                                NaN                      No
# 2731                                NaN                      No
# 3058                                NaN                      No
# 3535                                NaN                      No
#
# [138 rows x 39 columns]

# %%
b = smash[['5 digit NTD ID','City']]
m = m.merge(b, how = 'left', left_on = 'NTD ID', right_on = '5 digit NTD ID')
m
# Out:
#                                              Agency         City_x State  \
# 0    Washington Metropolitan Area Transit Authority     Washington    DC
# 1    Washington Metropolitan Area Transit Authority     Washington    DC
# 2    Washington Metropolitan Area Transit Authority     Washington    DC
# 3    Washington Metropolitan Area Transit Authority     Washington    DC
# 4    Washington Metropolitan Area Transit Authority     Washington    DC
# ..                                              ...            ...   ...
# 680   City of Seattle, dba: Seattle Center Monorail        Seattle    WA
# 681   City of Grand Prairie , dba: Grand Connection  Grand Prairie    TX
# 682                   City of Fairfax, dba: CUE Bus        Fairfax    VA
# 683               McKinney Avenue Transit Authority         Dallas    TX
# 684                                County of Pierce         Tacoma    WA
#
#     Legacy NTD ID NTD ID                                  Organization Type  \
# 0            3030  30030  Independent Public Agency or Authority of Tran...
# 1            3030  30030  Independent Public Agency or Authority of Tran...
# 2            3030  30030  Independent Public Agency or Authority of Tran...
# 3            3030  30030  Independent Public Agency or Authority of Tran...
# 4            3030  30030  Independent Public Agency or Authority of Tran...
# ..            ...    ...                                                ...
# 680            23     23  City, County or Local Government Unit or Depar...
# 681          6068  60068  City, County or Local Government Unit or Depar...
# 682          3058  30058  City, County or Local Government Unit or Depar...
# 683          6133  60133                     Private-Non-Profit Corporation
# 684            28     28  City, County or Local Government Unit or Depar...
#
#         Reporter Type  Primary UZA\n Population  Agency VOMS Mode  ...  \
# 0       Full Reporter                   4586770         3391   MB  ...
# 1       Full Reporter                   4586770         3391   MB  ...
# 2       Full Reporter                   4586770         3391   MB  ...
# 3       Full Reporter                   4586770         3391   MB  ...
# 4       Full Reporter                   4586770         3391   MB  ...
# ..                ...                       ...          ...  ...  ...
# 680     Full Reporter                   3059393            8   MG  ...
# 681  Reduced Reporter                   5121892            8   DR  ...
# 682     Full Reporter                   4586770            8   MB  ...
# 683     Full Reporter                   5121892            5   SR  ...
# 684     Full Reporter                   3059393            2   FB  ...
#
#     Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 0                                     NaN                  57911
# 1                                     NaN                  57911
# 2                                     NaN                  57911
# 3                                     NaN                  57911
# 4                                     NaN                  57911
# ..                                    ...                    ...
# 680                                   NaN                  20041
# 681                                   NaN                  13057
# 682                                   NaN                  34273
# 683                                   NaN                  12995
# 684                                   NaN                   5248
#
#      Vehicle Revenue Hours Questionable  Passenger Miles  \
# 0                                   NaN          9025834
# 1                                   NaN          9025834
# 2                                   NaN          9025834
# 3                                   NaN          9025834
# 4                                   NaN          9025834
# ..                                  ...              ...
# 680                                 NaN          1745302
# 681                                 NaN                0
# 682                                 NaN          2040146
# 683                                 NaN           721986
# 684                                 NaN          1823639
#
#     Passenger Miles Questionable  Vehicle Revenue Miles  \
# 0                            NaN                 901961
# 1                            NaN                 901961
# 2                            NaN                 901961
# 3                            NaN                 901961
# 4                            NaN                 901961
# ..                           ...                    ...
# 680                          NaN                 195517
# 681                          NaN                 140835
# 682                          NaN                 435847
# 683                          NaN                  61459
# 684                          NaN                  41557
#
#      Vehicle Revenue Miles Questionable  Any data questionable?  \
# 0                                   NaN                      No
# 1                                   NaN                      No
# 2                                   NaN                      No
# 3                                   NaN                      No
# 4                                   NaN                      No
# ..                                  ...                     ...
# 680                                 NaN                      No
# 681                                 NaN                      No
# 682                                 NaN                      No
# 683                                 NaN                      No
# 684                                 NaN                      No
#
#     5 digit NTD ID                       City_y
# 0            30030                   Washington
# 1            30030                   Washington
# 2            30030                   Washington
# 3            30030                   Washington
# 4            30030                   Washington
# ..             ...                          ...
# 680             23                      Seattle
# 681          60068  Dallas-Fort Worth-Arlington
# 682          30058                   Washington
# 683          60133  Dallas-Fort Worth-Arlington
# 684             28                      Seattle
#
# [685 rows x 41 columns]

# %%
list(m)
m = m[['Agency',
 'City_y',
 'State',
 'Legacy NTD ID',
 'NTD ID',
 'Organization Type',
 'Reporter Type',
 'Primary UZA\n Population',
 'Agency VOMS',
 'Mode',
 'TOS',
 'Mode VOMS',
 'Ratios:',
 'Fare Revenues per Unlinked Passenger Trip ',
 'Fare Revenues per Unlinked Passenger Trip Questionable',
 'Fare Revenues per Total Operating Expense (Recovery Ratio)',
 'Fare Revenues per Total Operating Expense (Recovery Ratio) Questionable',
 'Cost per\n Hour',
 'Cost per Hour Questionable',
 'Passengers per Hour',
 'Passengers per Hour Questionable',
 'Cost per Passenger',
 'Cost per Passenger Questionable',
 'Cost per Passenger Mile',
 'Cost per Passenger Mile Questionable',
 'Source Data:',
 'Fare Revenues Earned',
 'Fare Revenues Earned Questionable',
 'Total Operating Expenses',
 'Total Operating Expenses Questionable',
 'Unlinked Passenger Trips',
 'Unlinked Passenger Trips Questionable',
 'Vehicle Revenue Hours',
 'Vehicle Revenue Hours Questionable',
 'Passenger Miles',
 'Passenger Miles Questionable',
 'Vehicle Revenue Miles',
 'Vehicle Revenue Miles Questionable',
 'Any data questionable?']]

# %%
m = m.rename(columns = {'City_y':'City'})
m
# Out:
#                                              Agency  \
# 0    Washington Metropolitan Area Transit Authority
# 1    Washington Metropolitan Area Transit Authority
# 2    Washington Metropolitan Area Transit Authority
# 3    Washington Metropolitan Area Transit Authority
# 4    Washington Metropolitan Area Transit Authority
# ..                                              ...
# 680   City of Seattle, dba: Seattle Center Monorail
# 681   City of Grand Prairie , dba: Grand Connection
# 682                   City of Fairfax, dba: CUE Bus
# 683               McKinney Avenue Transit Authority
# 684                                County of Pierce
#
#                             City State Legacy NTD ID NTD ID  \
# 0                     Washington    DC          3030  30030
# 1                     Washington    DC          3030  30030
# 2                     Washington    DC          3030  30030
# 3                     Washington    DC          3030  30030
# 4                     Washington    DC          3030  30030
# ..                           ...   ...           ...    ...
# 680                      Seattle    WA            23     23
# 681  Dallas-Fort Worth-Arlington    TX          6068  60068
# 682                   Washington    VA          3058  30058
# 683  Dallas-Fort Worth-Arlington    TX          6133  60133
# 684                      Seattle    WA            28     28
#
#                                      Organization Type     Reporter Type  \
# 0    Independent Public Agency or Authority of Tran...     Full Reporter
# 1    Independent Public Agency or Authority of Tran...     Full Reporter
# 2    Independent Public Agency or Authority of Tran...     Full Reporter
# 3    Independent Public Agency or Authority of Tran...     Full Reporter
# 4    Independent Public Agency or Authority of Tran...     Full Reporter
# ..                                                 ...               ...
# 680  City, County or Local Government Unit or Depar...     Full Reporter
# 681  City, County or Local Government Unit or Depar...  Reduced Reporter
# 682  City, County or Local Government Unit or Depar...     Full Reporter
# 683                     Private-Non-Profit Corporation     Full Reporter
# 684  City, County or Local Government Unit or Depar...     Full Reporter
#
#      Primary UZA\n Population  Agency VOMS Mode  ...  \
# 0                     4586770         3391   MB  ...
# 1                     4586770         3391   MB  ...
# 2                     4586770         3391   MB  ...
# 3                     4586770         3391   MB  ...
# 4                     4586770         3391   MB  ...
# ..                        ...          ...  ...  ...
# 680                   3059393            8   MG  ...
# 681                   5121892            8   DR  ...
# 682                   4586770            8   MB  ...
# 683                   5121892            5   SR  ...
# 684                   3059393            2   FB  ...
#
#     Total Operating Expenses Questionable  Unlinked Passenger Trips  \
# 0                                     NaN                   1206050
# 1                                     NaN                   1206050
# 2                                     NaN                   1206050
# 3                                     NaN                   1206050
# 4                                     NaN                   1206050
# ..                                    ...                       ...
# 680                                   NaN                   1939224
# 681                                   NaN                     53404
# 682                                   NaN                    601813
# 683                                   NaN                    571801
# 684                                   NaN                    460515
#
#      Unlinked Passenger Trips Questionable  Vehicle Revenue Hours  \
# 0                                      NaN                  57911
# 1                                      NaN                  57911
# 2                                      NaN                  57911
# 3                                      NaN                  57911
# 4                                      NaN                  57911
# ..                                     ...                    ...
# 680                                    NaN                  20041
# 681                                    NaN                  13057
# 682                                    NaN                  34273
# 683                                    NaN                  12995
# 684                                    NaN                   5248
#
#     Vehicle Revenue Hours Questionable  Passenger Miles  \
# 0                                  NaN          9025834
# 1                                  NaN          9025834
# 2                                  NaN          9025834
# 3                                  NaN          9025834
# 4                                  NaN          9025834
# ..                                 ...              ...
# 680                                NaN          1745302
# 681                                NaN                0
# 682                                NaN          2040146
# 683                                NaN           721986
# 684                                NaN          1823639
#
#      Passenger Miles Questionable  Vehicle Revenue Miles  \
# 0                             NaN                 901961
# 1                             NaN                 901961
# 2                             NaN                 901961
# 3                             NaN                 901961
# 4                             NaN                 901961
# ..                            ...                    ...
# 680                           NaN                 195517
# 681                           NaN                 140835
# 682                           NaN                 435847
# 683                           NaN                  61459
# 684                           NaN                  41557
#
#     Vehicle Revenue Miles Questionable  Any data questionable?
# 0                                  NaN                      No
# 1                                  NaN                      No
# 2                                  NaN                      No
# 3                                  NaN                      No
# 4                                  NaN                      No
# ..                                 ...                     ...
# 680                                NaN                      No
# 681                                NaN                      No
# 682                                NaN                      No
# 683                                NaN                      No
# 684                                NaN                      No
#
# [685 rows x 39 columns]

# %%
ffares = m.groupby('City')['Fare Revenues Earned'].sum()
ffares = pd.DataFrame(ffares).reset_index()
ffares['Count in Millions'] = ffares['Fare Revenues Earned']/1000000
ffares = ffares.sort_values(by = 'Count in Millions', ascending = False)
ffares
# Out:
#                           City  Fare Revenues Earned  Count in Millions
# 6        San Francisco-Oakland            4188612606        4188.612606
# 8                   Washington            3689083273        3689.083273
# 7                      Seattle            2777495330        2777.495330
# 2                Denver-Aurora            1235894775        1235.894775
# 1  Dallas-Fort Worth-Arlington             726250961         726.250961
# 4                 Jacksonville              98625768          98.625768
# 3                 Indianapolis              65513182          65.513182
# 5           Nashville-Davidson              50053869          50.053869
# 0                     Columbus              41479502          41.479502

# %%
eexpenses = m.groupby('City')['Total Operating Expenses'].sum()
eexpenses = pd.DataFrame(eexpenses).reset_index()
eexpenses['Count in Millions'] = eexpenses['Total Operating Expenses']/1000000
eexpenses = eexpenses.sort_values(by = 'Count in Millions', ascending = False)
eexpenses
# Out:
#                           City  Total Operating Expenses  Count in Millions
# 6        San Francisco-Oakland               13041274445       13041.274445
# 7                      Seattle               11689650422       11689.650422
# 8                   Washington               11542455098       11542.455098
# 1  Dallas-Fort Worth-Arlington                6252109959        6252.109959
# 2                Denver-Aurora                5155766968        5155.766968
# 4                 Jacksonville                 909267784         909.267784
# 3                 Indianapolis                 669204941         669.204941
# 5           Nashville-Davidson                 452878244         452.878244
# 0                     Columbus                 353333701         353.333701

# %%
ffe = ffares.merge(eexpenses, on = 'City')
ffe = ffe.rename(columns = {'Count in Millions_x':'Renenues in Millions', 'Count in Millions_y':'Expenses in Millions'})
ffe['City'] = ffe['City'].str.replace('Dallas-Fort Worth-Arlington','Dallas-Fort')

# %%
ffe
# Out:
#                     City  Fare Revenues Earned  Renenues in Millions  \
# 0  San Francisco-Oakland            4188612606           4188.612606
# 1             Washington            3689083273           3689.083273
# 2                Seattle            2777495330           2777.495330
# 3          Denver-Aurora            1235894775           1235.894775
# 4            Dallas-Fort             726250961            726.250961
# 5           Jacksonville              98625768             98.625768
# 6           Indianapolis              65513182             65.513182
# 7     Nashville-Davidson              50053869             50.053869
# 8               Columbus              41479502             41.479502
#
#    Total Operating Expenses  Expenses in Millions
# 0               13041274445          13041.274445
# 1               11542455098          11542.455098
# 2               11689650422          11689.650422
# 3                5155766968           5155.766968
# 4                6252109959           6252.109959
# 5                 909267784            909.267784
# 6                 669204941            669.204941
# 7                 452878244            452.878244
# 8                 353333701            353.333701

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    s['City'],
    s['Count in Millions']
)

plt.xlabel("City", fontsize=16, fontweight='bold')
plt.ylabel("Count of Passenger Trips(Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Ridership Count');

# %%
plt.style.use('bmh')
plt.figure(figsize=(20, 9))

plt.bar(
    ffe['City'],
    ffe['Expenses in Millions'],
    label = 'Total Expenses in Millions',
    color = 'orange'
)

plt.bar(
    ffe['City'],
    ffe['Renenues in Millions'],
    label = 'Fare Renenues in Millions',
    color = 'blue'
)

plt.xlabel("City", fontsize=16, fontweight='bold')
plt.ylabel("Dollars (Millions)", fontsize=16, fontweight='bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend()
plt.title('Revenue and Expenses');

# %%
year_upt_df.to_csv(r'../data/public transportation/year_upt.csv', index = False)
